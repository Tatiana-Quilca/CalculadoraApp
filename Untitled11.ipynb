# %% [markdown]
# <a href="https://colab.research.google.com/github/Tatiana-Quilca/CalculadoraApp/blob/master/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# --- Configuración del modelo ---
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6  # 0-background, 1-Cow-tongue, 2-Dandelion, 3-Kikuyo, 4-Other, 5-Potato
BATCH_SIZE = 16
EPOCHS = 50
LEARNING_RATE = 1e-4

# --- Paths ---
BASE_PATH = '/content/Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')

# --- Módulos del modelo ---
class ASPPModule(layers.Layer):
    def __init__(self, filters=64, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters

        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False, kernel_regularizer=regularizers.l2(0.01))
        self.bn_1x1 = layers.BatchNormalization()

        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False, kernel_regularizer=regularizers.l2(0.01))
        self.bn_3x3_6 = layers.BatchNormalization()

        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False, kernel_regularizer=regularizers.l2(0.01))
        self.bn_3x3_12 = layers.BatchNormalization()

        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False, kernel_regularizer=regularizers.l2(0.01))
        self.bn_1x1_gap = layers.BatchNormalization()

        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False, kernel_regularizer=regularizers.l2(0.01))
        self.bn_final = layers.BatchNormalization()
        self.dropout = layers.Dropout(0.3)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)

        conv_1x1 = self.bn_1x1(self.conv_1x1(inputs), training=training)
        conv_3x3_6 = self.bn_3x3_6(self.conv_3x3_6(inputs), training=training)
        conv_3x3_12 = self.bn_3x3_12(self.conv_3x3_12(inputs), training=training)

        gap = self.global_avg_pool(inputs)
        gap = self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training)
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')

        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, gap])

        output = self.bn_final(self.conv_final(concat), training=training)
        output = self.dropout(output, training=training)

        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False, kernel_regularizer=regularizers.l2(0.01))
        self.bn_attention = layers.BatchNormalization()

        self.feature_conv = layers.Conv2D(self.filters, 3, padding='same', activation='relu', name='feature_processing_conv', use_bias=False, kernel_regularizer=regularizers.l2(0.01))
        self.bn_feature = layers.BatchNormalization()

        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.bn_feature(self.feature_conv(inputs), training=training)
        attended_features = features * attention_weights
        return attended_features

def create_efficient_backbone(input_shape):
    base_model = tf.keras.applications.EfficientNetV2B0(
        input_shape=input_shape,
        weights=None,
        include_top=False
    )

    layer_names = [
        'block1a_project_activation',
        'block2a_expand_activation',
        'block3a_expand_activation',
        'block4a_expand_activation',
        'top_activation'
    ]

    outputs = [base_model.get_layer(name).output for name in layer_names]

    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2B0_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)

    backbone = create_efficient_backbone(input_shape)
    backbone_features = backbone(inputs)

    deep_features = backbone_features[-1]
    mid_features = backbone_features[-3]

    aspp_features = ASPPModule(filters=64)(deep_features)
    attended_features = DeformableAttention(filters=64)(aspp_features)

    decoder_features = layers.Conv2DTranspose(64, 2, strides=2, padding='same', use_bias=False, kernel_regularizer=regularizers.l2(0.01))(attended_features)
    decoder_features = layers.BatchNormalization()(decoder_features)
    decoder_features = layers.Dropout(0.3)(decoder_features)
    decoder_features = layers.Conv2DTranspose(64, 2, strides=2, padding='same', use_bias=False, kernel_regularizer=regularizers.l2(0.01))(decoder_features)
    decoder_features = layers.BatchNormalization()(decoder_features)

    mid_processed = layers.Conv2D(32, 1, padding='same', use_bias=False, kernel_regularizer=regularizers.l2(0.01))(mid_features)
    mid_processed = layers.BatchNormalization()(mid_processed)

    decoder_concat = layers.Concatenate()([decoder_features, mid_processed])

    decoder_conv1 = layers.Conv2D(64, 3, padding='same', use_bias=False, kernel_regularizer=regularizers.l2(0.01))(decoder_concat)
    decoder_conv1 = layers.BatchNormalization()(decoder_conv1)
    decoder_conv1 = layers.Dropout(0.3)(decoder_conv1)
    decoder_conv2 = layers.Conv2D(64, 3, padding='same', use_bias=False, kernel_regularizer=regularizers.l2(0.01))(decoder_conv1)
    decoder_conv2 = layers.BatchNormalization()(decoder_conv2)

    final_upsample = layers.Conv2DTranspose(num_classes, 2, strides=2, padding='same', use_bias=False, kernel_regularizer=regularizers.l2(0.01))(decoder_conv2)
    final_upsample = layers.BatchNormalization()(final_upsample)
    final_upsample = layers.Conv2DTranspose(num_classes, 2, strides=2, padding='same', use_bias=False, kernel_regularizer=regularizers.l2(0.01))(final_upsample)
    final_upsample = layers.BatchNormalization()(final_upsample)
    final_upsample = layers.Conv2DTranspose(num_classes, 2, strides=2, padding='same', use_bias=False, kernel_regularizer=regularizers.l2(0.01))(final_upsample)
    final_upsample = layers.BatchNormalization()(final_upsample)

    outputs = layers.Conv2D(num_classes, 1, padding='same', activation='softmax', name='segmentation_output')(final_upsample)

    model = Model(inputs=inputs, outputs=outputs, name='WeedDetectionModel')

    return model

# --- Métricas y Funciones de Pérdida ---
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(y_true, [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(y_pred, [-1, NUM_CLASSES])

    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)

    return tf.reduce_mean(dice_scores)

def weighted_categorical_crossentropy(weights):
    def loss(y_true, y_pred):
        # Scale predictions so that the class probabilities of each sample sum to 1
        y_pred /= tf.reduce_sum(y_pred, axis=-1, keepdims=True)
        # Clip to prevent NaN's and Inf's
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        # Calculate cross entropy
        loss = y_true * tf.math.log(y_pred) * weights
        return -tf.reduce_sum(loss, axis=-1)

    return loss

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    class_weights = tf.constant([1.0, 2.0, 2.0, 1.0, 1.0, 2.0])  # Ajusta los pesos según la importancia de cada clase
    ce_loss = weighted_categorical_crossentropy(class_weights)(y_true, y_pred)
    d_loss = dice_loss(y_true, y_pred)
    return ce_loss + d_loss

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection

    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection

    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

# --- Carga y Preprocesamiento de Datos ---
def load_and_preprocess_data(images_path, masks_path):
    def load_image(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
        image = tf.cast(image, tf.float32) / 255.0
        return image

    def load_mask(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    image_paths = sorted(glob(os.path.join(images_path, '*.jpg')))
    mask_paths = sorted(glob(os.path.join(masks_path, '*.png')))

    if not image_paths:
        raise FileNotFoundError(f"No image files found in: {images_path}. Check path and file extensions.")
    if not mask_paths:
        raise FileNotFoundError(f"No mask files found in: {masks_path}. Check path and file extensions.")

    if len(image_paths) != len(mask_paths):
        print(f"DEBUG: Found {len(image_paths)} images and {len(mask_paths)} masks.")
        print("DEBUG: First 5 image files:", [os.path.basename(p) for p in image_paths[:5]])
        print("DEBUG: First 5 mask files:", [os.path.basename(p) for p in mask_paths[:5]])
        raise ValueError("Number of images and masks do not match. Check filenames and ensure a 1-to-1 correspondence.")

    print(f"Found {len(image_paths)} images and {len(mask_paths)} masks")

    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    mask_ds = tf.data.Dataset.from_tensor_slices(mask_paths).map(load_mask, num_parallel_calls=tf.data.AUTOTUNE)

    dataset = tf.data.Dataset.zip((image_ds, mask_ds))

    return dataset

def augment_data(image, mask):
    if tf.random.uniform([]) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform([]) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    if tf.random.uniform([]) > 0.5:
        k = tf.random.uniform([], maxval=4, dtype=tf.int32)
        image = tf.image.rot90(image, k)
        mask = tf.image.rot90(mask, k)

    image = tf.image.random_brightness(image, max_delta=0.5)
    image = tf.image.random_contrast(image, lower=0.5, upper=1.5)

    image = tf.clip_by_value(image, 0.0, 1.0)

    return image, mask

def create_datasets(validation_split=0.2):
    train_dataset = load_and_preprocess_data(TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH)
    val_dataset = load_and_preprocess_data(VAL_IMAGES_PATH, VAL_MASKS_PATH)

    train_dataset = train_dataset.shuffle(buffer_size=1000)
    val_dataset = val_dataset.shuffle(buffer_size=1000)

    train_dataset = train_dataset.map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    val_dataset = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    return train_dataset, val_dataset

def train_model(train_dataset, val_dataset, model_save_path='best_weed_model.h5'):
    model = create_weed_detection_model()
    model.summary()

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy']
    )

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            model_save_path,
            monitor='val_dice_coefficient',
            save_best_only=True,
            mode='max',
            verbose=1
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_dice_coefficient',
            patience=20,
            mode='max',
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=10,
            min_lr=1e-7,
            verbose=1
        )
    ]

    print(f"Starting training for {EPOCHS} epochs...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )

    return model, history

def visualize_predictions(model, val_dataset, num_samples=4):
    class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']

    print(f"Visualizing {num_samples} samples from the validation set...")

    for images, masks in val_dataset.take(1):
        predictions = model.predict(images)

        fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))

        for i in range(min(num_samples, images.shape[0])):
            axes[i, 0].imshow(images[i])
            axes[i, 0].set_title('Original Image')
            axes[i, 0].axis('off')

            true_mask = np.argmax(masks[i].numpy(), axis=-1)
            axes[i, 1].imshow(true_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 1].set_title('True Mask')
            axes[i, 1].axis('off')

            pred_mask = np.argmax(predictions[i], axis=-1)
            axes[i, 2].imshow(pred_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 2].set_title('Predicted Mask')
            axes[i, 2].axis('off')

        plt.tight_layout()
        plt.show()
        break

# --- Ejecución principal ---
if __name__ == "__main__":
    if not os.path.exists(TRAIN_IMAGES_PATH):
        print(f"Error: La ruta de imágenes de entrenamiento NO existe: {TRAIN_IMAGES_PATH}")
        exit()
    if not os.path.exists(TRAIN_MASKS_PATH):
        print(f"Error: La ruta de máscaras de entrenamiento NO existe: {TRAIN_MASKS_PATH}")
        exit()
    if not os.path.exists(VAL_IMAGES_PATH):
        print(f"Error: La ruta de imágenes de validación NO existe: {VAL_IMAGES_PATH}")
        exit()
    if not os.path.exists(VAL_MASKS_PATH):
        print(f"Error: La ruta de máscaras de validación NO existe: {VAL_MASKS_PATH}")
        exit()

    print("Creando datasets...")
    train_ds, val_ds = create_datasets()

    print("Entrenando modelo...")
    model, history = train_model(train_ds, val_ds)

    print("Visualizando predicciones...")
    visualize_predictions(model, val_ds)

    print("¡Entrenamiento completado! El mejor modelo se guardó como 'best_weed_model.h5'")

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['dice_coefficient'], label='Dice Coeff (Train)')
    plt.plot(history.history['val_dice_coefficient'], label='Dice Coeff (Validation)')
    plt.title('Dice Coefficient over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Dice Coefficient')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Loss (Train)')
    plt.plot(history.history['val_loss'], label='Loss (Validation)')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.show()

    print("\nEvaluando el modelo final en el conjunto de validación:")
    final_metrics = model.evaluate(val_ds)
    print(f"Validation Loss: {final_metrics[0]:.4f}")
    print(f"Validation Dice Coefficient: {final_metrics[1]:.4f}")
    print(f"Validation IoU: {final_metrics[2]:.4f}")
    print(f"Validation Accuracy: {final_metrics[3]:.4f}")

    iou_per_class_values = []
    for images, masks in val_ds:
        predictions = model.predict(images)
        iou_per_class_values.append(iou_per_class(masks, predictions))

    iou_per_class_values = np.mean(iou_per_class_values, axis=0)
    class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
    for i, iou in enumerate(iou_per_class_values):
        print(f"IoU for {class_names[i]}: {iou:.4f}")
# Out:
# Creando datasets...
# Found 1680 images and 1680 masks
# Found 210 images and 210 masks
# Entrenando modelo...
# Model: "WeedDetectionModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2B0_B… │ [(None, 64, 64,   │  5,919,312 │ input_layer_2[0]… │
# │ (Functional)        │ 16), (None, 32,   │            │                   │
# │                     │ 32, 64), (None,   │            │                   │
# │                     │ 16, 16, 128),     │            │                   │
# │                     │ (None, 16, 16,    │            │                   │
# │                     │ 192), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module_1       │ (None, 4, 4, 64)  │  1,656,064 │ EfficientNetV2B0… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 64)  │     41,472 │ aspp_module_1[0]… │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_5  │ (None, 8, 8, 64)  │     16,384 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_6  │ (None, 16, 16,    │     16,384 │ dropout_4[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 16, 16,    │      4,096 │ EfficientNetV2B0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 96)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 16, 16,    │     55,296 │ concatenate_10[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 16, 16,    │     36,864 │ dropout_5[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_7  │ (None, 32, 32, 6) │      1,536 │ batch_normalizat… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 6) │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 64, 64, 6) │        144 │ batch_normalizat… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64, 6) │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (None, 128, 128,  │        144 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ batch_normalizat… │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,748,962 (29.56 MB)
#  Trainable params: 7,686,846 (29.32 MB)
#  Non-trainable params: 62,116 (242.64 KB)
# Starting training for 50 epochs...
# Epoch 1/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.1459 - dice_coefficient: 0.0869 - iou_metric: 0.0788 - loss: 12.7480
# Epoch 1: val_dice_coefficient improved from -inf to 0.08470, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 130s 220ms/step - accuracy: 0.1461 - dice_coefficient: 0.0869 - iou_metric: 0.0789 - loss: 12.7376 - val_accuracy: 0.1530 - val_dice_coefficient: 0.0847 - val_iou_metric: 0.0828 - val_loss: 10.4314 - learning_rate: 1.0000e-04
# Epoch 2/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.2904 - dice_coefficient: 0.0890 - iou_metric: 0.1728 - loss: 9.1325
# Epoch 2: val_dice_coefficient improved from 0.08470 to 0.09124, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.2910 - dice_coefficient: 0.0890 - iou_metric: 0.1732 - loss: 9.1273 - val_accuracy: 0.7545 - val_dice_coefficient: 0.0912 - val_iou_metric: 0.6366 - val_loss: 7.4890 - learning_rate: 1.0000e-04
# Epoch 3/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4751 - dice_coefficient: 0.0916 - iou_metric: 0.3213 - loss: 7.2006
# Epoch 3: val_dice_coefficient improved from 0.09124 to 0.10815, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 84ms/step - accuracy: 0.4754 - dice_coefficient: 0.0916 - iou_metric: 0.3216 - loss: 7.1971 - val_accuracy: 0.2987 - val_dice_coefficient: 0.1081 - val_iou_metric: 0.1765 - val_loss: 7.9851 - learning_rate: 1.0000e-04
# Epoch 4/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5721 - dice_coefficient: 0.1017 - iou_metric: 0.4135 - loss: 5.8563
# Epoch 4: val_dice_coefficient did not improve from 0.10815
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.5723 - dice_coefficient: 0.1017 - iou_metric: 0.4137 - loss: 5.8539 - val_accuracy: 0.0573 - val_dice_coefficient: 0.0573 - val_iou_metric: 0.0309 - val_loss: 8.1785 - learning_rate: 1.0000e-04
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6660 - dice_coefficient: 0.1201 - iou_metric: 0.5169 - loss: 4.8875
# Epoch 5: val_dice_coefficient did not improve from 0.10815
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.6662 - dice_coefficient: 0.1201 - iou_metric: 0.5172 - loss: 4.8857 - val_accuracy: 0.0707 - val_dice_coefficient: 0.0543 - val_iou_metric: 0.0478 - val_loss: 8.3273 - learning_rate: 1.0000e-04
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7463 - dice_coefficient: 0.1321 - iou_metric: 0.6168 - loss: 4.1743
# Epoch 6: val_dice_coefficient improved from 0.10815 to 0.14846, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 83ms/step - accuracy: 0.7464 - dice_coefficient: 0.1321 - iou_metric: 0.6170 - loss: 4.1730 - val_accuracy: 0.6513 - val_dice_coefficient: 0.1485 - val_iou_metric: 0.5011 - val_loss: 7.9797 - learning_rate: 1.0000e-04
# Epoch 7/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8038 - dice_coefficient: 0.1493 - iou_metric: 0.6950 - loss: 3.6351
# Epoch 7: val_dice_coefficient improved from 0.14846 to 0.15394, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 85ms/step - accuracy: 0.8040 - dice_coefficient: 0.1493 - iou_metric: 0.6954 - loss: 3.6331 - val_accuracy: 0.7300 - val_dice_coefficient: 0.1539 - val_iou_metric: 0.5936 - val_loss: 6.1502 - learning_rate: 1.0000e-04
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8281 - dice_coefficient: 0.1558 - iou_metric: 0.7327 - loss: 3.2561
# Epoch 8: val_dice_coefficient did not improve from 0.15394
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.8281 - dice_coefficient: 0.1559 - iou_metric: 0.7327 - loss: 3.2554 - val_accuracy: 0.1015 - val_dice_coefficient: 0.0391 - val_iou_metric: 0.0616 - val_loss: 15.7600 - learning_rate: 1.0000e-04
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8483 - dice_coefficient: 0.1675 - iou_metric: 0.7587 - loss: 2.9473
# Epoch 9: val_dice_coefficient did not improve from 0.15394
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.8483 - dice_coefficient: 0.1675 - iou_metric: 0.7587 - loss: 2.9467 - val_accuracy: 0.1000 - val_dice_coefficient: 0.0546 - val_iou_metric: 0.0588 - val_loss: 6.2539 - learning_rate: 1.0000e-04
# Epoch 10/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8487 - dice_coefficient: 0.1799 - iou_metric: 0.7586 - loss: 2.7044
# Epoch 10: val_dice_coefficient did not improve from 0.15394
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.8487 - dice_coefficient: 0.1799 - iou_metric: 0.7586 - loss: 2.7040 - val_accuracy: 0.1019 - val_dice_coefficient: 0.0474 - val_iou_metric: 0.0794 - val_loss: 13.1039 - learning_rate: 1.0000e-04
# Epoch 11/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8571 - dice_coefficient: 0.1865 - iou_metric: 0.7692 - loss: 2.5168
# Epoch 11: val_dice_coefficient did not improve from 0.15394
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8571 - dice_coefficient: 0.1866 - iou_metric: 0.7692 - loss: 2.5161 - val_accuracy: 0.3151 - val_dice_coefficient: 0.1154 - val_iou_metric: 0.1900 - val_loss: 7.3187 - learning_rate: 1.0000e-04
# Epoch 12/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8607 - dice_coefficient: 0.1986 - iou_metric: 0.7756 - loss: 2.3506
# Epoch 12: val_dice_coefficient did not improve from 0.15394
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8607 - dice_coefficient: 0.1985 - iou_metric: 0.7757 - loss: 2.3503 - val_accuracy: 0.2338 - val_dice_coefficient: 0.0907 - val_iou_metric: 0.1327 - val_loss: 5.9548 - learning_rate: 1.0000e-04
# Epoch 13/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8717 - dice_coefficient: 0.2064 - iou_metric: 0.7902 - loss: 2.2055
# Epoch 13: val_dice_coefficient improved from 0.15394 to 0.15657, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 78ms/step - accuracy: 0.8717 - dice_coefficient: 0.2064 - iou_metric: 0.7901 - loss: 2.2055 - val_accuracy: 0.6173 - val_dice_coefficient: 0.1566 - val_iou_metric: 0.4878 - val_loss: 2.8969 - learning_rate: 1.0000e-04
# Epoch 14/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8707 - dice_coefficient: 0.2125 - iou_metric: 0.7882 - loss: 2.1234
# Epoch 14: val_dice_coefficient did not improve from 0.15657
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - accuracy: 0.8707 - dice_coefficient: 0.2125 - iou_metric: 0.7883 - loss: 2.1232 - val_accuracy: 0.4387 - val_dice_coefficient: 0.1321 - val_iou_metric: 0.2831 - val_loss: 4.2827 - learning_rate: 1.0000e-04
# Epoch 15/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8727 - dice_coefficient: 0.2171 - iou_metric: 0.7916 - loss: 2.0417
# Epoch 15: val_dice_coefficient did not improve from 0.15657
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.8727 - dice_coefficient: 0.2171 - iou_metric: 0.7915 - loss: 2.0416 - val_accuracy: 0.1105 - val_dice_coefficient: 0.0626 - val_iou_metric: 0.0650 - val_loss: 6.5047 - learning_rate: 1.0000e-04
# Epoch 16/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8733 - dice_coefficient: 0.2171 - iou_metric: 0.7930 - loss: 1.9869
# Epoch 16: val_dice_coefficient did not improve from 0.15657
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.8733 - dice_coefficient: 0.2172 - iou_metric: 0.7930 - loss: 1.9867 - val_accuracy: 0.1295 - val_dice_coefficient: 0.0540 - val_iou_metric: 0.0760 - val_loss: 7.9797 - learning_rate: 1.0000e-04
# Epoch 17/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8792 - dice_coefficient: 0.2319 - iou_metric: 0.7993 - loss: 1.8899
# Epoch 17: val_dice_coefficient did not improve from 0.15657
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.8792 - dice_coefficient: 0.2319 - iou_metric: 0.7992 - loss: 1.8901 - val_accuracy: 0.1048 - val_dice_coefficient: 0.0401 - val_iou_metric: 0.0741 - val_loss: 15.9264 - learning_rate: 1.0000e-04
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8812 - dice_coefficient: 0.2382 - iou_metric: 0.8028 - loss: 1.8294
# Epoch 18: val_dice_coefficient did not improve from 0.15657
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8812 - dice_coefficient: 0.2381 - iou_metric: 0.8029 - loss: 1.8293 - val_accuracy: 0.2380 - val_dice_coefficient: 0.0830 - val_iou_metric: 0.1379 - val_loss: 4.4619 - learning_rate: 1.0000e-04
# Epoch 19/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8801 - dice_coefficient: 0.2438 - iou_metric: 0.8029 - loss: 1.7781
# Epoch 19: val_dice_coefficient did not improve from 0.15657
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.8802 - dice_coefficient: 0.2438 - iou_metric: 0.8029 - loss: 1.7781 - val_accuracy: 0.1511 - val_dice_coefficient: 0.0622 - val_iou_metric: 0.0826 - val_loss: 9.7491 - learning_rate: 1.0000e-04
# Epoch 20/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8820 - dice_coefficient: 0.2454 - iou_metric: 0.8041 - loss: 1.7475
# Epoch 20: val_dice_coefficient did not improve from 0.15657
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.8820 - dice_coefficient: 0.2454 - iou_metric: 0.8041 - loss: 1.7472 - val_accuracy: 0.1034 - val_dice_coefficient: 0.0362 - val_iou_metric: 0.0608 - val_loss: 13.9805 - learning_rate: 1.0000e-04
# Epoch 21/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8832 - dice_coefficient: 0.2554 - iou_metric: 0.8062 - loss: 1.6828
# Epoch 21: val_dice_coefficient did not improve from 0.15657
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - accuracy: 0.8832 - dice_coefficient: 0.2554 - iou_metric: 0.8062 - loss: 1.6828 - val_accuracy: 0.6560 - val_dice_coefficient: 0.1479 - val_iou_metric: 0.5053 - val_loss: 7.2624 - learning_rate: 1.0000e-04
# Epoch 22/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8878 - dice_coefficient: 0.2623 - iou_metric: 0.8119 - loss: 1.6336
# Epoch 22: val_dice_coefficient did not improve from 0.15657
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8878 - dice_coefficient: 0.2623 - iou_metric: 0.8119 - loss: 1.6336 - val_accuracy: 0.2160 - val_dice_coefficient: 0.0814 - val_iou_metric: 0.1214 - val_loss: 7.4960 - learning_rate: 1.0000e-04
# Epoch 23/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8907 - dice_coefficient: 0.2670 - iou_metric: 0.8175 - loss: 1.5883
# Epoch 23: val_dice_coefficient did not improve from 0.15657
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - accuracy: 0.8907 - dice_coefficient: 0.2669 - iou_metric: 0.8175 - loss: 1.5884 - val_accuracy: 0.1031 - val_dice_coefficient: 0.0415 - val_iou_metric: 0.0629 - val_loss: 11.0857 - learning_rate: 1.0000e-04
# Epoch 24/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8842 - dice_coefficient: 0.2658 - iou_metric: 0.8084 - loss: 1.5983
# Epoch 24: val_dice_coefficient did not improve from 0.15657
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8843 - dice_coefficient: 0.2658 - iou_metric: 0.8084 - loss: 1.5983 - val_accuracy: 0.1004 - val_dice_coefficient: 0.0313 - val_iou_metric: 0.0611 - val_loss: 15.1133 - learning_rate: 5.0000e-05
# Epoch 25/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8909 - dice_coefficient: 0.2765 - iou_metric: 0.8175 - loss: 1.5357
# Epoch 25: val_dice_coefficient improved from 0.15657 to 0.20877, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 81ms/step - accuracy: 0.8909 - dice_coefficient: 0.2765 - iou_metric: 0.8175 - loss: 1.5359 - val_accuracy: 0.7650 - val_dice_coefficient: 0.2088 - val_iou_metric: 0.6389 - val_loss: 2.1206 - learning_rate: 5.0000e-05
# Epoch 26/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8898 - dice_coefficient: 0.2760 - iou_metric: 0.8156 - loss: 1.5388
# Epoch 26: val_dice_coefficient improved from 0.20877 to 0.26790, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.8898 - dice_coefficient: 0.2760 - iou_metric: 0.8156 - loss: 1.5388 - val_accuracy: 0.8729 - val_dice_coefficient: 0.2679 - val_iou_metric: 0.7956 - val_loss: 1.5371 - learning_rate: 5.0000e-05
# Epoch 27/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8945 - dice_coefficient: 0.2723 - iou_metric: 0.8229 - loss: 1.5138
# Epoch 27: val_dice_coefficient did not improve from 0.26790
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.8944 - dice_coefficient: 0.2723 - iou_metric: 0.8228 - loss: 1.5139 - val_accuracy: 0.8261 - val_dice_coefficient: 0.1662 - val_iou_metric: 0.7392 - val_loss: 2.4229 - learning_rate: 5.0000e-05
# Epoch 28/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8942 - dice_coefficient: 0.2795 - iou_metric: 0.8222 - loss: 1.4978
# Epoch 28: val_dice_coefficient did not improve from 0.26790
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.8941 - dice_coefficient: 0.2794 - iou_metric: 0.8222 - loss: 1.4980 - val_accuracy: 0.1005 - val_dice_coefficient: 0.0350 - val_iou_metric: 0.0763 - val_loss: 14.9492 - learning_rate: 5.0000e-05
# Epoch 29/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8928 - dice_coefficient: 0.2859 - iou_metric: 0.8202 - loss: 1.4760
# Epoch 29: val_dice_coefficient did not improve from 0.26790
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 71ms/step - accuracy: 0.8928 - dice_coefficient: 0.2858 - iou_metric: 0.8202 - loss: 1.4762 - val_accuracy: 0.1003 - val_dice_coefficient: 0.0448 - val_iou_metric: 0.0652 - val_loss: 14.3828 - learning_rate: 5.0000e-05
# Epoch 30/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8950 - dice_coefficient: 0.2751 - iou_metric: 0.8235 - loss: 1.4916
# Epoch 30: val_dice_coefficient did not improve from 0.26790
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.8950 - dice_coefficient: 0.2751 - iou_metric: 0.8235 - loss: 1.4915 - val_accuracy: 0.8488 - val_dice_coefficient: 0.2092 - val_iou_metric: 0.7647 - val_loss: 1.9038 - learning_rate: 5.0000e-05
# Epoch 31/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8919 - dice_coefficient: 0.2878 - iou_metric: 0.8189 - loss: 1.4619
# Epoch 31: val_dice_coefficient did not improve from 0.26790
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8919 - dice_coefficient: 0.2877 - iou_metric: 0.8189 - loss: 1.4620 - val_accuracy: 0.1005 - val_dice_coefficient: 0.0296 - val_iou_metric: 0.0618 - val_loss: 15.6123 - learning_rate: 5.0000e-05
# Epoch 32/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8963 - dice_coefficient: 0.2886 - iou_metric: 0.8251 - loss: 1.4364
# Epoch 32: val_dice_coefficient did not improve from 0.26790
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 66ms/step - accuracy: 0.8963 - dice_coefficient: 0.2886 - iou_metric: 0.8251 - loss: 1.4364 - val_accuracy: 0.0584 - val_dice_coefficient: 0.0624 - val_iou_metric: 0.0354 - val_loss: 6.9913 - learning_rate: 5.0000e-05
# Epoch 33/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8895 - dice_coefficient: 0.2871 - iou_metric: 0.8151 - loss: 1.4660
# Epoch 33: val_dice_coefficient did not improve from 0.26790
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 73ms/step - accuracy: 0.8895 - dice_coefficient: 0.2871 - iou_metric: 0.8151 - loss: 1.4659 - val_accuracy: 0.7253 - val_dice_coefficient: 0.1794 - val_iou_metric: 0.5930 - val_loss: 2.3090 - learning_rate: 5.0000e-05
# Epoch 34/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8902 - dice_coefficient: 0.2908 - iou_metric: 0.8168 - loss: 1.4489
# Epoch 34: val_dice_coefficient did not improve from 0.26790
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8902 - dice_coefficient: 0.2908 - iou_metric: 0.8169 - loss: 1.4490 - val_accuracy: 0.0723 - val_dice_coefficient: 0.0413 - val_iou_metric: 0.0381 - val_loss: 15.0980 - learning_rate: 5.0000e-05
# Epoch 35/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8991 - dice_coefficient: 0.2937 - iou_metric: 0.8278 - loss: 1.4067
# Epoch 35: val_dice_coefficient did not improve from 0.26790
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.8991 - dice_coefficient: 0.2937 - iou_metric: 0.8278 - loss: 1.4068 - val_accuracy: 0.1004 - val_dice_coefficient: 0.0390 - val_iou_metric: 0.0629 - val_loss: 14.5083 - learning_rate: 5.0000e-05
# Epoch 36/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8926 - dice_coefficient: 0.2993 - iou_metric: 0.8207 - loss: 1.4100
# Epoch 36: val_dice_coefficient did not improve from 0.26790
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8926 - dice_coefficient: 0.2992 - iou_metric: 0.8208 - loss: 1.4101 - val_accuracy: 0.7627 - val_dice_coefficient: 0.1740 - val_iou_metric: 0.6292 - val_loss: 2.3817 - learning_rate: 5.0000e-05
# Epoch 37/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8942 - dice_coefficient: 0.2945 - iou_metric: 0.8227 - loss: 1.4036
# Epoch 37: val_dice_coefficient improved from 0.26790 to 0.27280, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 82ms/step - accuracy: 0.8942 - dice_coefficient: 0.2945 - iou_metric: 0.8227 - loss: 1.4036 - val_accuracy: 0.8749 - val_dice_coefficient: 0.2728 - val_iou_metric: 0.7740 - val_loss: 1.5525 - learning_rate: 2.5000e-05
# Epoch 38/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8978 - dice_coefficient: 0.2984 - iou_metric: 0.8274 - loss: 1.3870
# Epoch 38: val_dice_coefficient did not improve from 0.27280
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.8978 - dice_coefficient: 0.2984 - iou_metric: 0.8274 - loss: 1.3871 - val_accuracy: 0.1241 - val_dice_coefficient: 0.1051 - val_iou_metric: 0.0744 - val_loss: 6.2880 - learning_rate: 2.5000e-05
# Epoch 39/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9000 - dice_coefficient: 0.3069 - iou_metric: 0.8309 - loss: 1.3518
# Epoch 39: val_dice_coefficient did not improve from 0.27280
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8999 - dice_coefficient: 0.3068 - iou_metric: 0.8309 - loss: 1.3521 - val_accuracy: 0.2385 - val_dice_coefficient: 0.0876 - val_iou_metric: 0.1688 - val_loss: 4.9763 - learning_rate: 2.5000e-05
# Epoch 40/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8936 - dice_coefficient: 0.2955 - iou_metric: 0.8213 - loss: 1.4059
# Epoch 40: val_dice_coefficient did not improve from 0.27280
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.8936 - dice_coefficient: 0.2955 - iou_metric: 0.8213 - loss: 1.4058 - val_accuracy: 0.0921 - val_dice_coefficient: 0.0370 - val_iou_metric: 0.0543 - val_loss: 14.1704 - learning_rate: 2.5000e-05
# Epoch 41/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8953 - dice_coefficient: 0.2947 - iou_metric: 0.8240 - loss: 1.3999
# Epoch 41: val_dice_coefficient did not improve from 0.27280
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.8953 - dice_coefficient: 0.2947 - iou_metric: 0.8240 - loss: 1.3998 - val_accuracy: 0.6806 - val_dice_coefficient: 0.1642 - val_iou_metric: 0.5305 - val_loss: 2.6597 - learning_rate: 2.5000e-05
# Epoch 42/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8930 - dice_coefficient: 0.3008 - iou_metric: 0.8209 - loss: 1.3786
# Epoch 42: val_dice_coefficient did not improve from 0.27280
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - accuracy: 0.8930 - dice_coefficient: 0.3008 - iou_metric: 0.8209 - loss: 1.3786 - val_accuracy: 0.8419 - val_dice_coefficient: 0.2301 - val_iou_metric: 0.7537 - val_loss: 1.9010 - learning_rate: 2.5000e-05
# Epoch 43/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8937 - dice_coefficient: 0.3046 - iou_metric: 0.8210 - loss: 1.3665
# Epoch 43: val_dice_coefficient improved from 0.27280 to 0.29208, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - accuracy: 0.8937 - dice_coefficient: 0.3045 - iou_metric: 0.8210 - loss: 1.3666 - val_accuracy: 0.8841 - val_dice_coefficient: 0.2921 - val_iou_metric: 0.8100 - val_loss: 1.4738 - learning_rate: 2.5000e-05
# Epoch 44/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8947 - dice_coefficient: 0.3014 - iou_metric: 0.8237 - loss: 1.3670
# Epoch 44: val_dice_coefficient did not improve from 0.29208
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.8947 - dice_coefficient: 0.3014 - iou_metric: 0.8237 - loss: 1.3670 - val_accuracy: 0.8327 - val_dice_coefficient: 0.2407 - val_iou_metric: 0.7294 - val_loss: 1.8200 - learning_rate: 2.5000e-05
# Epoch 45/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8936 - dice_coefficient: 0.3012 - iou_metric: 0.8215 - loss: 1.3761
# Epoch 45: val_dice_coefficient did not improve from 0.29208
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.8937 - dice_coefficient: 0.3012 - iou_metric: 0.8216 - loss: 1.3759 - val_accuracy: 0.1404 - val_dice_coefficient: 0.0494 - val_iou_metric: 0.0837 - val_loss: 8.7352 - learning_rate: 2.5000e-05
# Epoch 46/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8956 - dice_coefficient: 0.3045 - iou_metric: 0.8245 - loss: 1.3607
# Epoch 46: val_dice_coefficient did not improve from 0.29208
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.8956 - dice_coefficient: 0.3045 - iou_metric: 0.8245 - loss: 1.3606 - val_accuracy: 0.6226 - val_dice_coefficient: 0.1663 - val_iou_metric: 0.4518 - val_loss: 2.7337 - learning_rate: 2.5000e-05
# Epoch 47/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8882 - dice_coefficient: 0.3028 - iou_metric: 0.8161 - loss: 1.3892
# Epoch 47: val_dice_coefficient did not improve from 0.29208
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - accuracy: 0.8883 - dice_coefficient: 0.3027 - iou_metric: 0.8161 - loss: 1.3891 - val_accuracy: 0.6027 - val_dice_coefficient: 0.1856 - val_iou_metric: 0.4703 - val_loss: 2.4533 - learning_rate: 2.5000e-05
# Epoch 48/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8971 - dice_coefficient: 0.3052 - iou_metric: 0.8262 - loss: 1.3456
# Epoch 48: val_dice_coefficient did not improve from 0.29208
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 72ms/step - accuracy: 0.8971 - dice_coefficient: 0.3052 - iou_metric: 0.8262 - loss: 1.3457 - val_accuracy: 0.1031 - val_dice_coefficient: 0.0342 - val_iou_metric: 0.0606 - val_loss: 10.7372 - learning_rate: 2.5000e-05
# Epoch 49/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8936 - dice_coefficient: 0.3073 - iou_metric: 0.8221 - loss: 1.3513
# Epoch 49: val_dice_coefficient improved from 0.29208 to 0.33203, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 12s 87ms/step - accuracy: 0.8936 - dice_coefficient: 0.3073 - iou_metric: 0.8221 - loss: 1.3513 - val_accuracy: 0.9094 - val_dice_coefficient: 0.3320 - val_iou_metric: 0.8428 - val_loss: 1.2429 - learning_rate: 2.5000e-05
# Epoch 50/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8970 - dice_coefficient: 0.3147 - iou_metric: 0.8265 - loss: 1.3231
# Epoch 50: val_dice_coefficient did not improve from 0.33203
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.8969 - dice_coefficient: 0.3146 - iou_metric: 0.8265 - loss: 1.3233 - val_accuracy: 0.8752 - val_dice_coefficient: 0.2951 - val_iou_metric: 0.7866 - val_loss: 1.4324 - learning_rate: 2.5000e-05
# Visualizando predicciones...
# Visualizing 4 samples from the validation set...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# ¡Entrenamiento completado! El mejor modelo se guardó como 'best_weed_model.h5'
# Evaluando el modelo final en el conjunto de validación:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9083 - dice_coefficient: 0.3282 - iou_metric: 0.8436 - loss: 1.2504
# Validation Loss: 1.2460
# Validation Dice Coefficient: 0.3182
# Validation IoU: 0.8502
# Validation Accuracy: 0.9094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# IoU for Background: 0.9270
# IoU for Cow-tongue: 0.4003
# IoU for Dandelion: 0.2315
# IoU for Kikuyo: 0.2993
# IoU for Other: 0.6652
# IoU for Potato: 0.6103
