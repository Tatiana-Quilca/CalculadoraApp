# %% [markdown]
# <a href="https://colab.research.google.com/github/Tatiana-Quilca/CalculadoraApp/blob/master/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model, regularizers
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# --- Configuración del modelo ---
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6   # 0-background, 1-Cow-tongue, 2-Dandelion, 3-Kikuyo, 4-Other, 5-Potato
BATCH_SIZE = 8    # Reducido debido al mayor tamaño del modelo
EPOCHS = 150
LEARNING_RATE = 5e-5  # Reducido para modelo más grande

# --- Paths ---
BASE_PATH = './Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')

# --- Módulos del modelo ---
class ASPPModule(layers.Layer):
    def __init__(self, filters=256, **kwargs):  # Aumentado para EfficientNetV2S
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters

        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()
        self.relu_1x1 = layers.ReLU()

        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()
        self.relu_3x3_6 = layers.ReLU()

        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()
        self.relu_3x3_12 = layers.ReLU()

        self.conv_3x3_18 = layers.Conv2D(filters, 3, padding='same', dilation_rate=18, use_bias=False)
        self.bn_3x3_18 = layers.BatchNormalization()
        self.relu_3x3_18 = layers.ReLU()

        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()
        self.relu_1x1_gap = layers.ReLU()

        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.relu_final = layers.ReLU()
        self.dropout = layers.Dropout(0.3)  # Aumentado para mejor regularización

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)

        conv_1x1 = self.relu_1x1(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_6 = self.relu_3x3_6(self.bn_3x3_6(self.conv_3x3_6(inputs), training=training))
        conv_3x3_12 = self.relu_3x3_12(self.bn_3x3_12(self.conv_3x3_12(inputs), training=training))
        conv_3x3_18 = self.relu_3x3_18(self.bn_3x3_18(self.conv_3x3_18(inputs), training=training))

        gap = self.global_avg_pool(inputs)
        gap = self.relu_1x1_gap(self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training))
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')

        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, conv_3x3_18, gap])

        output = self.relu_final(self.bn_final(self.conv_final(concat), training=training))
        output = self.dropout(output, training=training)

        return output

class DeformableAttention(layers.Layer):
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()

        self.feature_conv = layers.SeparableConv2D(self.filters, 3, padding='same', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()
        self.relu_feature = layers.ReLU()

        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.relu_feature(self.bn_feature(self.feature_conv(inputs), training=training))
        attended_features = features * attention_weights
        return attended_features

def create_efficient_backbone(input_shape):
    # Cambio principal: EfficientNetV2B0 -> EfficientNetV2S
    base_model = tf.keras.applications.EfficientNetV2S(
        input_shape=input_shape,
        weights='imagenet',
        include_top=False
    )
    base_model.trainable = True

    # Capas de características para EfficientNetV2S - nombres actualizados
    layer_names = [
        'block1a_project_activation',  # Expected: (N, 64, 64, 24)
        'block2b_add',                 # Expected: (N, 32, 32, 48)
        'block3b_add',                 # Expected: (N, 16, 16, 64)
        'block5e_add',                 # Expected: (N, 8, 8, 160)
        'top_activation'               # Expected: (N, 4, 4, 1280)
    ]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2S_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)
    backbone = create_efficient_backbone(input_shape)

    # Unpack outputs directly from the backbone call
    feat1_out, feat2_out, feat3_out, feat4_out, feat5_out = backbone(inputs)

    # --- DEBUGGING PRINTS ---
    print(f"\n--- EfficientNetV2S Backbone Feature Shapes ---")
    print(f"feat1_out (64x64): {feat1_out.shape}")
    print(f"feat2_out (32x32): {feat2_out.shape}")
    print(f"feat3_out (16x16): {feat3_out.shape}")
    print(f"feat4_out (8x8): {feat4_out.shape}")
    print(f"feat5_out (4x4, ASPP input): {feat5_out.shape}")
    print(f"-------------------------------\n")
    # --- END DEBUGGING PRINTS ---

    deep_features = feat5_out  # (N, 4, 4, 1280) -> input to ASPP
    aspp_filters = 256  # Incrementado para EfficientNetV2S
    aspp_features = ASPPModule(filters=aspp_filters)(deep_features)  # (N, 4, 4, 256)
    attended_features = DeformableAttention(filters=aspp_filters)(aspp_features)  # (N, 4, 4, 256)

    # --- Decoder Path - Ajustado para EfficientNetV2S ---

    # UP1: From (4,4) to (8,8)
    decoder_up1 = layers.Conv2DTranspose(128, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_up1 = layers.BatchNormalization()(decoder_up1)
    decoder_up1 = layers.ReLU()(decoder_up1)
    decoder_up1 = layers.Dropout(0.3)(decoder_up1)
    print(f"Shape of decoder_up1 (after upsampling from 4x4): {decoder_up1.shape}")

    # Concat with feat4_out (8x8, 160 channels)
    feat4_processed = layers.Conv2D(128, 1, padding='same', use_bias=False)(feat4_out)
    feat4_processed = layers.BatchNormalization()(feat4_processed)
    feat4_processed = layers.ReLU()(feat4_processed)
    print(f"Shape of feat4_processed (from 8x8 backbone feature): {feat4_processed.shape}")

    decoder_concat_8x8 = layers.Concatenate()([decoder_up1, feat4_processed])
    print(f"Shape of decoder_concat_8x8: {decoder_concat_8x8.shape}")

    decoder_conv_8x8 = layers.SeparableConv2D(128, 3, padding='same', use_bias=False)(decoder_concat_8x8)
    decoder_conv_8x8 = layers.BatchNormalization()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.ReLU()(decoder_conv_8x8)
    decoder_conv_8x8 = layers.Dropout(0.3)(decoder_conv_8x8)

    # UP2: From (8,8) to (16,16)
    decoder_up2 = layers.Conv2DTranspose(96, 2, strides=2, padding='same', use_bias=False)(decoder_conv_8x8)
    decoder_up2 = layers.BatchNormalization()(decoder_up2)
    decoder_up2 = layers.ReLU()(decoder_up2)
    decoder_up2 = layers.Dropout(0.3)(decoder_up2)

    # Concat with feat3_out (16x16, 64 channels)
    feat3_processed = layers.Conv2D(96, 1, padding='same', use_bias=False)(feat3_out)
    feat3_processed = layers.BatchNormalization()(feat3_processed)
    feat3_processed = layers.ReLU()(feat3_processed)

    decoder_concat_16x16 = layers.Concatenate()([decoder_up2, feat3_processed])
    decoder_conv_16x16 = layers.SeparableConv2D(96, 3, padding='same', use_bias=False)(decoder_concat_16x16)
    decoder_conv_16x16 = layers.BatchNormalization()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.ReLU()(decoder_conv_16x16)
    decoder_conv_16x16 = layers.Dropout(0.3)(decoder_conv_16x16)

    # UP3: From (16,16) to (32,32)
    decoder_up3 = layers.Conv2DTranspose(64, 2, strides=2, padding='same', use_bias=False)(decoder_conv_16x16)
    decoder_up3 = layers.BatchNormalization()(decoder_up3)
    decoder_up3 = layers.ReLU()(decoder_up3)
    decoder_up3 = layers.Dropout(0.3)(decoder_up3)

    # Concat with feat2_out (32x32, 48 channels)
    feat2_processed = layers.Conv2D(64, 1, padding='same', use_bias=False)(feat2_out)
    feat2_processed = layers.BatchNormalization()(feat2_processed)
    feat2_processed = layers.ReLU()(feat2_processed)

    decoder_concat_32x32 = layers.Concatenate()([decoder_up3, feat2_processed])
    decoder_conv_32x32 = layers.SeparableConv2D(64, 3, padding='same', use_bias=False)(decoder_concat_32x32)
    decoder_conv_32x32 = layers.BatchNormalization()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.ReLU()(decoder_conv_32x32)
    decoder_conv_32x32 = layers.Dropout(0.3)(decoder_conv_32x32)

    # UP4: From (32,32) to (64,64)
    decoder_up4 = layers.Conv2DTranspose(32, 2, strides=2, padding='same', use_bias=False)(decoder_conv_32x32)
    decoder_up4 = layers.BatchNormalization()(decoder_up4)
    decoder_up4 = layers.ReLU()(decoder_up4)
    decoder_up4 = layers.Dropout(0.3)(decoder_up4)

    # Concat with feat1_out (64x64, 24 channels)
    feat1_processed = layers.Conv2D(32, 1, padding='same', use_bias=False)(feat1_out)
    feat1_processed = layers.BatchNormalization()(feat1_processed)
    feat1_processed = layers.ReLU()(feat1_processed)

    decoder_concat_64x64 = layers.Concatenate()([decoder_up4, feat1_processed])
    decoder_conv_64x64 = layers.SeparableConv2D(32, 3, padding='same', use_bias=False)(decoder_concat_64x64)
    decoder_conv_64x64 = layers.BatchNormalization()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.ReLU()(decoder_conv_64x64)
    decoder_conv_64x64 = layers.Dropout(0.3)(decoder_conv_64x64)

    # Final Upsampling to IMG_HEIGHT, IMG_WIDTH (128x128)
    outputs = layers.Conv2DTranspose(NUM_CLASSES, 2, strides=2, padding='same', use_bias=False)(decoder_conv_64x64)
    outputs = layers.Conv2D(NUM_CLASSES, 1, padding='same', activation='softmax', name='segmentation_output')(outputs)
    print(f"Shape of final outputs: {outputs.shape}")

    model = Model(inputs=inputs, outputs=outputs, name='EfficientV2S_WeedDetectionModel')
    return model

# --- Métricas y Funciones de Pérdida (sin cambios) ---
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.reshape(tf.cast(y_true, tf.float32), [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(tf.cast(y_pred, tf.float32), [-1, NUM_CLASSES])
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)
    return tf.reduce_mean(dice_scores)

def focal_loss(gamma=2.0, alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha * tf.pow(1 - y_pred, gamma) * cross_entropy
        return loss
    return focal_loss_fixed

def dice_loss(y_true, y_pred):
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    class_weights = tf.constant([0.4, 4.0, 3.5, 1.0, 2.0, 4.0])
    f_loss_per_pixel_per_class = focal_loss(gamma=2.0, alpha=0.75)(y_true, y_pred)
    weighted_f_loss = f_loss_per_pixel_per_class * class_weights
    f_loss_reduced = tf.reduce_sum(weighted_f_loss, axis=-1)
    f_loss_mean = tf.reduce_mean(f_loss_reduced)
    d_loss = dice_loss(y_true, y_pred)
    return f_loss_mean + (1.5 * d_loss)

def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection
    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)

# --- Carga y Preprocesamiento de Datos ---
def load_and_preprocess_data(train_img_path, train_msk_path, val_img_path, val_msk_path):
    def load_image_only(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH], method='bilinear')
        return tf.cast(image, tf.float32)

    def load_mask_only(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    def augment_and_preprocess(image, mask):
        if tf.random.uniform([]) > 0.5:
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)
        if tf.random.uniform([]) > 0.5:
            image = tf.image.flip_up_down(image)
            mask = tf.image.flip_up_down(mask)
        if tf.random.uniform([]) > 0.5:
            k = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
            image = tf.image.rot90(image, k)
            mask = tf.image.rot90(mask, k)
        image = tf.image.random_brightness(image, max_delta=0.4 * 255)
        image = tf.image.random_contrast(image, lower=0.6, upper=1.4)
        image = tf.image.random_hue(image, max_delta=0.15)
        image = tf.image.random_saturation(image, lower=0.6, upper=1.4)
        image = tf.clip_by_value(image, 0.0, 255.0)
        # Cambio: usar preprocess_input de EfficientNetV2S
        image = tf.keras.applications.efficientnet_v2.preprocess_input(image)
        return image, mask

    train_image_paths = sorted(glob(os.path.join(train_img_path, '*.jpg')))
    train_mask_paths = sorted(glob(os.path.join(train_msk_path, '*.png')))
    val_image_paths = sorted(glob(os.path.join(val_img_path, '*.jpg')))
    val_mask_paths = sorted(glob(os.path.join(val_msk_path, '*.png')))

    if not train_image_paths or not train_mask_paths or not val_image_paths or not val_mask_paths:
        raise FileNotFoundError("Una o más rutas de datos no encontraron archivos. Verifica las rutas.")

    print(f"Found {len(train_image_paths)} training images and {len(train_mask_paths)} training masks")
    print(f"Found {len(val_image_paths)} validation images and {len(val_mask_paths)} validation masks")

    train_image_ds = tf.data.Dataset.from_tensor_slices(train_image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    train_mask_ds = tf.data.Dataset.from_tensor_slices(train_mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    train_dataset = tf.data.Dataset.zip((train_image_ds, train_mask_ds))
    train_dataset = train_dataset.shuffle(buffer_size=1000).map(augment_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    val_image_ds = tf.data.Dataset.from_tensor_slices(val_image_paths).map(load_image_only, num_parallel_calls=tf.data.AUTOTUNE)
    val_mask_ds = tf.data.Dataset.from_tensor_slices(val_mask_paths).map(load_mask_only, num_parallel_calls=tf.data.AUTOTUNE)
    val_dataset = tf.data.Dataset.zip((val_image_ds, val_mask_ds))
    val_dataset = val_dataset.map(lambda img, mask: (tf.keras.applications.efficientnet_v2.preprocess_input(img), mask), num_parallel_calls=tf.data.AUTOTUNE)
    val_dataset = val_dataset.cache().batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    return train_dataset, val_dataset

def train_model(train_dataset, val_dataset, model_save_path='efficient_v2s_weed_model.keras'):
    model = create_weed_detection_model()
    model.summary()

    # Optimizador mejorado para EfficientNetV2S
    optimizer = tf.keras.optimizers.AdamW(
        learning_rate=LEARNING_RATE,
        weight_decay=2e-5,  # Aumentado para mejor regularización
        beta_1=0.9,
        beta_2=0.999
    )

    model.compile(
        optimizer=optimizer,
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy']
    )

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            model_save_path,
            monitor='val_dice_coefficient',
            save_best_only=True,
            mode='max',
            verbose=1,
            save_weights_only=False
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_dice_coefficient',
            patience=40,  # Reducido para modelo más grande
            mode='max',
            restore_best_weights=True,
            verbose=1
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,  # Reducción más agresiva
            patience=15,
            min_lr=1e-7,
            verbose=1
        ),
        # Callback adicional para monitorear el entrenamiento
        tf.keras.callbacks.CSVLogger('training_log_v2s.csv', append=True)
    ]

    print(f"Starting training with EfficientNetV2S for {EPOCHS} epochs...")
    print(f"Batch size: {BATCH_SIZE}, Learning rate: {LEARNING_RATE}")

    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )
    return model, history

def visualize_predictions(model, val_dataset, num_samples=4):
    print(f"Visualizing {num_samples} samples from the validation set...")
    for images, masks in val_dataset.take(1):
        predictions = model.predict(images)
        fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))
        for i in range(min(num_samples, images.shape[0])):
            original_image = images[i]
            original_image = (original_image - original_image.numpy().min()) / (original_image.numpy().max() - original_image.numpy().min() + 1e-8) * 255
            original_image = tf.cast(original_image, tf.uint8)

            axes[i, 0].imshow(original_image)
            axes[i, 0].set_title('Original Image')
            axes[i, 0].axis('off')

            true_mask = np.argmax(masks[i].numpy(), axis=-1)
            axes[i, 1].imshow(true_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 1].set_title('True Mask')
            axes[i, 1].axis('off')

            pred_mask = np.argmax(predictions[i], axis=-1)
            axes[i, 2].imshow(pred_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 2].set_title('Predicted Mask')
            axes[i, 2].axis('off')

        plt.tight_layout()
        plt.show()
        break

if __name__ == "__main__":
    # Verificar disponibilidad de GPU
    print("GPU Available: ", tf.config.list_physical_devices('GPU'))

    for path in [TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH, VAL_IMAGES_PATH, VAL_MASKS_PATH]:
        if not os.path.exists(path):
            print(f"Error: La ruta de datos NO existe: {path}")
            print(f"Creando directorio: {path}")
            os.makedirs(path, exist_ok=True)

    print("Creando datasets...")
    train_ds, val_ds = load_and_preprocess_data(TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH, VAL_IMAGES_PATH, VAL_MASKS_PATH)

    if not any(True for _ in train_ds.take(1)):
        print("Error: El dataset de entrenamiento está vacío. Asegúrate de que haya imágenes y máscaras en las rutas correctas.")
        exit()

    print("Entrenando modelo con EfficientNetV2S...")
    model_save_path = 'efficient_v2s_weed_model.keras'
    model, history = train_model(train_ds, val_ds, model_save_path=model_save_path)

    print("Visualizando predicciones...")
    visualize_predictions(model, val_ds)

    print(f"¡Entrenamiento completado! El mejor modelo se guardó como '{model_save_path}'")

    plt.figure(figsize=(15, 10))

    plt.subplot(2, 2, 1)
    plt.plot(history.history['dice_coefficient'], label='Dice Coeff (Train)', linewidth=2)
    plt.plot(history.history['val_dice_coefficient'], label='Dice Coeff (Validation)', linewidth=2)
    plt.title('Dice Coefficient over Epochs - EfficientNetV2S', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('Dice Coefficient')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(2, 2, 2)
    plt.plot(history.history['loss'], label='Loss (Train)', linewidth=2)
    plt.plot(history.history['val_loss'], label='Loss (Validation)', linewidth=2)
    plt.title('Loss over Epochs - EfficientNetV2S', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(2, 2, 3)
    plt.plot(history.history['iou_metric'], label='IoU (Train)', linewidth=2)
    plt.plot(history.history['val_iou_metric'], label='IoU (Validation)', linewidth=2)
    plt.title('IoU Metric over Epochs - EfficientNetV2S', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('IoU')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(2, 2, 4)
    plt.plot(history.history['accuracy'], label='Accuracy (Train)', linewidth=2)
    plt.plot(history.history['val_accuracy'], label='Accuracy (Validation)', linewidth=2)
    plt.title('Accuracy over Epochs - EfficientNetV2S', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

    print("\nEvaluando el modelo final en el conjunto de validación:")
    final_metrics = model.evaluate(val_ds)
    print(f"Validation Loss: {final_metrics[0]:.4f}")
    print(f"Validation Dice Coefficient: {final_metrics[1]:.4f}")
    print(f"Validation IoU: {final_metrics[2]:.4f}")
    print(f"Validation Accuracy: {final_metrics[3]:.4f}")

    iou_per_class_values = []
    print("Calculando IoU por clase...")
    for images_batch, masks_batch in val_ds:
        predictions_batch = model.predict(images_batch, verbose=0)
        iou_per_class_values.append(iou_per_class(masks_batch, predictions_batch))

    iou_per_class_values = tf.reduce_mean(tf.stack(iou_per_class_values), axis=0).numpy()

    class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
    print("\n--- IoU por Clase (EfficientNetV2S) ---")
    for i, iou in enumerate(iou_per_class_values):
        print(f"IoU for {class_names[i]}: {iou:.4f}")

    print(f"\nPromedio IoU por clase: {np.mean(iou_per_class_values):.4f}")
    print(f"Modelo guardado como: {model_save_path}")
    print(f"Log de entrenamiento guardado como: training_log_v2s.csv")
# Out:
# GPU Available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Creando datasets...
# Found 1680 training images and 1680 training masks
# Found 210 validation images and 210 validation masks
# Entrenando modelo con EfficientNetV2S...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# --- EfficientNetV2S Backbone Feature Shapes ---
# feat1_out (64x64): (None, 64, 64, 24)
# feat2_out (32x32): (None, 32, 32, 48)
# feat3_out (16x16): (None, 16, 16, 64)
# feat4_out (8x8): (None, 8, 8, 160)
# feat5_out (4x4, ASPP input): (None, 4, 4, 1280)
# -------------------------------
#
# Shape of decoder_up1 (after upsampling from 4x4): (None, 8, 8, 128)
# Shape of feat4_processed (from 8x8 backbone feature): (None, 8, 8, 128)
# Shape of decoder_concat_8x8: (None, 8, 8, 256)
# Shape of final outputs: (None, 128, 128, 6)
# Model: "EfficientV2S_WeedDetectionModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2S_Ba… │ [(None, 64, 64,   │ 20,331,360 │ input_layer[0][0] │
# │ (Functional)        │ 24), (None, 32,   │            │                   │
# │                     │ 32, 48), (None,   │            │                   │
# │                     │ 16, 16, 64),      │            │                   │
# │                     │ (None, 8, 8,      │            │                   │
# │                     │ 160), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module         │ (None, 4, 4, 256) │  9,836,544 │ EfficientNetV2S_… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 256) │    135,424 │ aspp_module[0][0] │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 128) │    131,072 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 128) │     20,480 │ EfficientNetV2S_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 8, 8, 128) │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 8, 8, 256) │          0 │ dropout_1[0][0],  │
# │ (Concatenate)       │                   │            │ re_lu_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 8, 8, 128) │     35,072 │ concatenate_2[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 128) │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 8, 8, 128) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 8, 8, 128) │          0 │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │     49,152 │ dropout_2[0][0]   │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │      6,144 │ EfficientNetV2S_… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_10[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 16, 16,    │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │ 192)              │            │ re_lu_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 16, 16,    │     20,160 │ concatenate_3[0]… │
# │ (SeparableConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        384 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 16, 16,    │          0 │ re_lu_12[0][0]    │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32,    │     24,576 │ dropout_4[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │      3,072 │ EfficientNetV2S_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_13[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32,    │          0 │ dropout_5[0][0],  │
# │ (Concatenate)       │ 128)              │            │ re_lu_14[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 32, 32,    │      9,344 │ concatenate_4[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 32, 32,    │          0 │ re_lu_15[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64,    │      8,192 │ dropout_6[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │        768 │ EfficientNetV2S_… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_16[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ dropout_7[0][0],  │
# │ (Concatenate)       │ 64)               │            │ re_lu_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 64, 64,    │      2,624 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 64,    │          0 │ re_lu_18[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │        768 │ dropout_8[0][0]   │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ conv2d_transpose… │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,618,634 (116.80 MB)
#  Trainable params: 30,458,746 (116.19 MB)
#  Non-trainable params: 159,888 (624.56 KB)
# Starting training with EfficientNetV2S for 150 epochs...
# Batch size: 8, Learning rate: 5e-05
# Epoch 1/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.1420 - dice_coefficient: 0.0879 - iou_metric: 0.0776 - loss: 2.3009
# Epoch 1: val_dice_coefficient improved from -inf to 0.08572, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 255s 255ms/step - accuracy: 0.1420 - dice_coefficient: 0.0879 - iou_metric: 0.0777 - loss: 2.3005 - val_accuracy: 0.2507 - val_dice_coefficient: 0.0857 - val_iou_metric: 0.1429 - val_loss: 2.2011 - learning_rate: 5.0000e-05
# Epoch 2/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.2486 - dice_coefficient: 0.1164 - iou_metric: 0.1472 - loss: 2.0228
# Epoch 2: val_dice_coefficient improved from 0.08572 to 0.09513, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 36s 167ms/step - accuracy: 0.2487 - dice_coefficient: 0.1164 - iou_metric: 0.1474 - loss: 2.0227 - val_accuracy: 0.4416 - val_dice_coefficient: 0.0951 - val_iou_metric: 0.2841 - val_loss: 2.0944 - learning_rate: 5.0000e-05
# Epoch 3/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4175 - dice_coefficient: 0.1343 - iou_metric: 0.2721 - loss: 1.8933
# Epoch 3: val_dice_coefficient improved from 0.09513 to 0.11843, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 41s 167ms/step - accuracy: 0.4177 - dice_coefficient: 0.1343 - iou_metric: 0.2723 - loss: 1.8932 - val_accuracy: 0.6846 - val_dice_coefficient: 0.1184 - val_iou_metric: 0.5233 - val_loss: 1.8769 - learning_rate: 5.0000e-05
# Epoch 4/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5907 - dice_coefficient: 0.1455 - iou_metric: 0.4317 - loss: 1.8245
# Epoch 4: val_dice_coefficient improved from 0.11843 to 0.14563, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 34s 158ms/step - accuracy: 0.5908 - dice_coefficient: 0.1455 - iou_metric: 0.4319 - loss: 1.8244 - val_accuracy: 0.8394 - val_dice_coefficient: 0.1456 - val_iou_metric: 0.7300 - val_loss: 1.7150 - learning_rate: 5.0000e-05
# Epoch 5/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.7351 - dice_coefficient: 0.1574 - iou_metric: 0.5982 - loss: 1.7509
# Epoch 5: val_dice_coefficient improved from 0.14563 to 0.15095, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 44s 171ms/step - accuracy: 0.7352 - dice_coefficient: 0.1574 - iou_metric: 0.5984 - loss: 1.7508 - val_accuracy: 0.8911 - val_dice_coefficient: 0.1510 - val_iou_metric: 0.8113 - val_loss: 1.6933 - learning_rate: 5.0000e-05
# Epoch 6/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8022 - dice_coefficient: 0.1702 - iou_metric: 0.6918 - loss: 1.6939
# Epoch 6: val_dice_coefficient improved from 0.15095 to 0.17668, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 41s 172ms/step - accuracy: 0.8022 - dice_coefficient: 0.1702 - iou_metric: 0.6918 - loss: 1.6938 - val_accuracy: 0.8919 - val_dice_coefficient: 0.1767 - val_iou_metric: 0.8125 - val_loss: 1.5732 - learning_rate: 5.0000e-05
# Epoch 7/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8301 - dice_coefficient: 0.1877 - iou_metric: 0.7305 - loss: 1.6189
# Epoch 7: val_dice_coefficient improved from 0.17668 to 0.19587, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 40s 168ms/step - accuracy: 0.8301 - dice_coefficient: 0.1877 - iou_metric: 0.7305 - loss: 1.6188 - val_accuracy: 0.8912 - val_dice_coefficient: 0.1959 - val_iou_metric: 0.8112 - val_loss: 1.5023 - learning_rate: 5.0000e-05
# Epoch 8/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8407 - dice_coefficient: 0.1960 - iou_metric: 0.7465 - loss: 1.5979
# Epoch 8: val_dice_coefficient improved from 0.19587 to 0.21166, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 38s 175ms/step - accuracy: 0.8407 - dice_coefficient: 0.1960 - iou_metric: 0.7465 - loss: 1.5978 - val_accuracy: 0.8875 - val_dice_coefficient: 0.2117 - val_iou_metric: 0.8055 - val_loss: 1.4550 - learning_rate: 5.0000e-05
# Epoch 9/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8464 - dice_coefficient: 0.2115 - iou_metric: 0.7539 - loss: 1.5595
# Epoch 9: val_dice_coefficient improved from 0.21166 to 0.22507, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 205ms/step - accuracy: 0.8464 - dice_coefficient: 0.2115 - iou_metric: 0.7539 - loss: 1.5594 - val_accuracy: 0.9008 - val_dice_coefficient: 0.2251 - val_iou_metric: 0.8265 - val_loss: 1.4292 - learning_rate: 5.0000e-05
# Epoch 10/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8542 - dice_coefficient: 0.2250 - iou_metric: 0.7637 - loss: 1.5064
# Epoch 10: val_dice_coefficient improved from 0.22507 to 0.23947, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 100s 293ms/step - accuracy: 0.8542 - dice_coefficient: 0.2250 - iou_metric: 0.7637 - loss: 1.5064 - val_accuracy: 0.8966 - val_dice_coefficient: 0.2395 - val_iou_metric: 0.8198 - val_loss: 1.3863 - learning_rate: 5.0000e-05
# Epoch 11/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8609 - dice_coefficient: 0.2368 - iou_metric: 0.7722 - loss: 1.4775
# Epoch 11: val_dice_coefficient improved from 0.23947 to 0.24646, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 67s 223ms/step - accuracy: 0.8609 - dice_coefficient: 0.2368 - iou_metric: 0.7722 - loss: 1.4774 - val_accuracy: 0.9006 - val_dice_coefficient: 0.2465 - val_iou_metric: 0.8260 - val_loss: 1.3768 - learning_rate: 5.0000e-05
# Epoch 12/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8690 - dice_coefficient: 0.2485 - iou_metric: 0.7844 - loss: 1.4471
# Epoch 12: val_dice_coefficient improved from 0.24646 to 0.25715, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 97s 292ms/step - accuracy: 0.8690 - dice_coefficient: 0.2485 - iou_metric: 0.7844 - loss: 1.4471 - val_accuracy: 0.9010 - val_dice_coefficient: 0.2572 - val_iou_metric: 0.8266 - val_loss: 1.3477 - learning_rate: 5.0000e-05
# Epoch 13/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8755 - dice_coefficient: 0.2585 - iou_metric: 0.7928 - loss: 1.4131
# Epoch 13: val_dice_coefficient improved from 0.25715 to 0.26404, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 61s 289ms/step - accuracy: 0.8755 - dice_coefficient: 0.2585 - iou_metric: 0.7928 - loss: 1.4131 - val_accuracy: 0.9054 - val_dice_coefficient: 0.2640 - val_iou_metric: 0.8334 - val_loss: 1.3257 - learning_rate: 5.0000e-05
# Epoch 14/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8819 - dice_coefficient: 0.2728 - iou_metric: 0.8027 - loss: 1.3747
# Epoch 14: val_dice_coefficient improved from 0.26404 to 0.27336, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 49s 231ms/step - accuracy: 0.8819 - dice_coefficient: 0.2728 - iou_metric: 0.8027 - loss: 1.3747 - val_accuracy: 0.9062 - val_dice_coefficient: 0.2734 - val_iou_metric: 0.8344 - val_loss: 1.3034 - learning_rate: 5.0000e-05
# Epoch 15/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8819 - dice_coefficient: 0.2758 - iou_metric: 0.8006 - loss: 1.3838
# Epoch 15: val_dice_coefficient improved from 0.27336 to 0.27982, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 49s 230ms/step - accuracy: 0.8819 - dice_coefficient: 0.2758 - iou_metric: 0.8006 - loss: 1.3837 - val_accuracy: 0.9127 - val_dice_coefficient: 0.2798 - val_iou_metric: 0.8450 - val_loss: 1.2947 - learning_rate: 5.0000e-05
# Epoch 16/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8813 - dice_coefficient: 0.2825 - iou_metric: 0.8005 - loss: 1.3522
# Epoch 16: val_dice_coefficient improved from 0.27982 to 0.28773, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 221ms/step - accuracy: 0.8813 - dice_coefficient: 0.2825 - iou_metric: 0.8005 - loss: 1.3522 - val_accuracy: 0.9100 - val_dice_coefficient: 0.2877 - val_iou_metric: 0.8408 - val_loss: 1.2667 - learning_rate: 5.0000e-05
# Epoch 17/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8852 - dice_coefficient: 0.2884 - iou_metric: 0.8052 - loss: 1.3231
# Epoch 17: val_dice_coefficient improved from 0.28773 to 0.29458, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 48s 223ms/step - accuracy: 0.8852 - dice_coefficient: 0.2885 - iou_metric: 0.8052 - loss: 1.3230 - val_accuracy: 0.9109 - val_dice_coefficient: 0.2946 - val_iou_metric: 0.8422 - val_loss: 1.2464 - learning_rate: 5.0000e-05
# Epoch 18/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8887 - dice_coefficient: 0.2978 - iou_metric: 0.8102 - loss: 1.2955
# Epoch 18: val_dice_coefficient improved from 0.29458 to 0.30874, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 96s 290ms/step - accuracy: 0.8887 - dice_coefficient: 0.2978 - iou_metric: 0.8102 - loss: 1.2955 - val_accuracy: 0.9139 - val_dice_coefficient: 0.3087 - val_iou_metric: 0.8471 - val_loss: 1.2122 - learning_rate: 5.0000e-05
# Epoch 19/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8839 - dice_coefficient: 0.3098 - iou_metric: 0.8047 - loss: 1.2860
# Epoch 19: val_dice_coefficient improved from 0.30874 to 0.31152, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 43s 199ms/step - accuracy: 0.8839 - dice_coefficient: 0.3098 - iou_metric: 0.8047 - loss: 1.2860 - val_accuracy: 0.9004 - val_dice_coefficient: 0.3115 - val_iou_metric: 0.8258 - val_loss: 1.1955 - learning_rate: 5.0000e-05
# Epoch 20/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8883 - dice_coefficient: 0.3147 - iou_metric: 0.8097 - loss: 1.2689
# Epoch 20: val_dice_coefficient improved from 0.31152 to 0.31922, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 52s 241ms/step - accuracy: 0.8883 - dice_coefficient: 0.3147 - iou_metric: 0.8097 - loss: 1.2688 - val_accuracy: 0.9007 - val_dice_coefficient: 0.3192 - val_iou_metric: 0.8265 - val_loss: 1.1744 - learning_rate: 5.0000e-05
# Epoch 21/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8930 - dice_coefficient: 0.3279 - iou_metric: 0.8173 - loss: 1.2381
# Epoch 21: val_dice_coefficient improved from 0.31922 to 0.32565, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 57s 269ms/step - accuracy: 0.8930 - dice_coefficient: 0.3279 - iou_metric: 0.8173 - loss: 1.2380 - val_accuracy: 0.9017 - val_dice_coefficient: 0.3256 - val_iou_metric: 0.8284 - val_loss: 1.1594 - learning_rate: 5.0000e-05
# Epoch 22/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8971 - dice_coefficient: 0.3389 - iou_metric: 0.8230 - loss: 1.2115
# Epoch 22: val_dice_coefficient improved from 0.32565 to 0.33270, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 74s 231ms/step - accuracy: 0.8971 - dice_coefficient: 0.3389 - iou_metric: 0.8230 - loss: 1.2115 - val_accuracy: 0.9021 - val_dice_coefficient: 0.3327 - val_iou_metric: 0.8292 - val_loss: 1.1494 - learning_rate: 5.0000e-05
# Epoch 23/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8967 - dice_coefficient: 0.3485 - iou_metric: 0.8227 - loss: 1.1827
# Epoch 23: val_dice_coefficient improved from 0.33270 to 0.34237, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 82s 230ms/step - accuracy: 0.8967 - dice_coefficient: 0.3485 - iou_metric: 0.8227 - loss: 1.1827 - val_accuracy: 0.9048 - val_dice_coefficient: 0.3424 - val_iou_metric: 0.8330 - val_loss: 1.1386 - learning_rate: 5.0000e-05
# Epoch 24/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8997 - dice_coefficient: 0.3581 - iou_metric: 0.8267 - loss: 1.1700
# Epoch 24: val_dice_coefficient improved from 0.34237 to 0.34779, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 88s 261ms/step - accuracy: 0.8997 - dice_coefficient: 0.3581 - iou_metric: 0.8267 - loss: 1.1700 - val_accuracy: 0.9055 - val_dice_coefficient: 0.3478 - val_iou_metric: 0.8336 - val_loss: 1.1244 - learning_rate: 5.0000e-05
# Epoch 25/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9056 - dice_coefficient: 0.3733 - iou_metric: 0.8354 - loss: 1.1219
# Epoch 25: val_dice_coefficient improved from 0.34779 to 0.35936, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 48s 225ms/step - accuracy: 0.9056 - dice_coefficient: 0.3733 - iou_metric: 0.8353 - loss: 1.1220 - val_accuracy: 0.9096 - val_dice_coefficient: 0.3594 - val_iou_metric: 0.8396 - val_loss: 1.1045 - learning_rate: 5.0000e-05
# Epoch 26/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9056 - dice_coefficient: 0.3842 - iou_metric: 0.8354 - loss: 1.1085
# Epoch 26: val_dice_coefficient improved from 0.35936 to 0.36513, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 52s 246ms/step - accuracy: 0.9056 - dice_coefficient: 0.3842 - iou_metric: 0.8354 - loss: 1.1086 - val_accuracy: 0.9060 - val_dice_coefficient: 0.3651 - val_iou_metric: 0.8333 - val_loss: 1.0890 - learning_rate: 5.0000e-05
# Epoch 27/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9101 - dice_coefficient: 0.3984 - iou_metric: 0.8425 - loss: 1.0829
# Epoch 27: val_dice_coefficient improved from 0.36513 to 0.37281, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 47s 221ms/step - accuracy: 0.9101 - dice_coefficient: 0.3984 - iou_metric: 0.8425 - loss: 1.0830 - val_accuracy: 0.9162 - val_dice_coefficient: 0.3728 - val_iou_metric: 0.8505 - val_loss: 1.0849 - learning_rate: 5.0000e-05
# Epoch 28/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9158 - dice_coefficient: 0.4048 - iou_metric: 0.8519 - loss: 1.0565
# Epoch 28: val_dice_coefficient improved from 0.37281 to 0.38233, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 82s 222ms/step - accuracy: 0.9158 - dice_coefficient: 0.4048 - iou_metric: 0.8518 - loss: 1.0566 - val_accuracy: 0.9195 - val_dice_coefficient: 0.3823 - val_iou_metric: 0.8559 - val_loss: 1.0609 - learning_rate: 5.0000e-05
# Epoch 29/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9115 - dice_coefficient: 0.4167 - iou_metric: 0.8454 - loss: 1.0579
# Epoch 29: val_dice_coefficient improved from 0.38233 to 0.38739, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 51s 241ms/step - accuracy: 0.9115 - dice_coefficient: 0.4167 - iou_metric: 0.8454 - loss: 1.0579 - val_accuracy: 0.9164 - val_dice_coefficient: 0.3874 - val_iou_metric: 0.8506 - val_loss: 1.0529 - learning_rate: 5.0000e-05
# Epoch 30/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9118 - dice_coefficient: 0.4138 - iou_metric: 0.8454 - loss: 1.0579
# Epoch 30: val_dice_coefficient improved from 0.38739 to 0.39444, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 86s 262ms/step - accuracy: 0.9118 - dice_coefficient: 0.4138 - iou_metric: 0.8454 - loss: 1.0578 - val_accuracy: 0.9217 - val_dice_coefficient: 0.3944 - val_iou_metric: 0.8597 - val_loss: 1.0411 - learning_rate: 5.0000e-05
# Epoch 31/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9140 - dice_coefficient: 0.4183 - iou_metric: 0.8490 - loss: 1.0541
# Epoch 31: val_dice_coefficient improved from 0.39444 to 0.39841, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 70s 204ms/step - accuracy: 0.9140 - dice_coefficient: 0.4183 - iou_metric: 0.8490 - loss: 1.0541 - val_accuracy: 0.9185 - val_dice_coefficient: 0.3984 - val_iou_metric: 0.8545 - val_loss: 1.0356 - learning_rate: 5.0000e-05
# Epoch 32/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9141 - dice_coefficient: 0.4284 - iou_metric: 0.8495 - loss: 1.0434
# Epoch 32: val_dice_coefficient improved from 0.39841 to 0.40384, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 49s 228ms/step - accuracy: 0.9141 - dice_coefficient: 0.4284 - iou_metric: 0.8495 - loss: 1.0434 - val_accuracy: 0.9269 - val_dice_coefficient: 0.4038 - val_iou_metric: 0.8685 - val_loss: 1.0305 - learning_rate: 5.0000e-05
# Epoch 33/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9142 - dice_coefficient: 0.4311 - iou_metric: 0.8491 - loss: 1.0245
# Epoch 33: val_dice_coefficient improved from 0.40384 to 0.40526, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 49s 229ms/step - accuracy: 0.9142 - dice_coefficient: 0.4311 - iou_metric: 0.8492 - loss: 1.0244 - val_accuracy: 0.9226 - val_dice_coefficient: 0.4053 - val_iou_metric: 0.8611 - val_loss: 1.0102 - learning_rate: 5.0000e-05
# Epoch 34/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9231 - dice_coefficient: 0.4398 - iou_metric: 0.8632 - loss: 1.0036
# Epoch 34: val_dice_coefficient improved from 0.40526 to 0.40745, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 88s 259ms/step - accuracy: 0.9231 - dice_coefficient: 0.4398 - iou_metric: 0.8632 - loss: 1.0036 - val_accuracy: 0.9243 - val_dice_coefficient: 0.4074 - val_iou_metric: 0.8640 - val_loss: 1.0064 - learning_rate: 5.0000e-05
# Epoch 35/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9224 - dice_coefficient: 0.4453 - iou_metric: 0.8626 - loss: 0.9822
# Epoch 35: val_dice_coefficient improved from 0.40745 to 0.41014, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 109s 386ms/step - accuracy: 0.9224 - dice_coefficient: 0.4453 - iou_metric: 0.8626 - loss: 0.9823 - val_accuracy: 0.9237 - val_dice_coefficient: 0.4101 - val_iou_metric: 0.8627 - val_loss: 1.0084 - learning_rate: 5.0000e-05
# Epoch 36/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9213 - dice_coefficient: 0.4587 - iou_metric: 0.8610 - loss: 0.9646
# Epoch 36: val_dice_coefficient improved from 0.41014 to 0.41784, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 51s 240ms/step - accuracy: 0.9213 - dice_coefficient: 0.4586 - iou_metric: 0.8610 - loss: 0.9646 - val_accuracy: 0.9270 - val_dice_coefficient: 0.4178 - val_iou_metric: 0.8684 - val_loss: 0.9875 - learning_rate: 5.0000e-05
# Epoch 37/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9260 - dice_coefficient: 0.4645 - iou_metric: 0.8685 - loss: 0.9546
# Epoch 37: val_dice_coefficient improved from 0.41784 to 0.41943, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 88s 268ms/step - accuracy: 0.9260 - dice_coefficient: 0.4644 - iou_metric: 0.8684 - loss: 0.9546 - val_accuracy: 0.9253 - val_dice_coefficient: 0.4194 - val_iou_metric: 0.8653 - val_loss: 0.9898 - learning_rate: 5.0000e-05
# Epoch 38/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9234 - dice_coefficient: 0.4678 - iou_metric: 0.8640 - loss: 0.9600
# Epoch 38: val_dice_coefficient did not improve from 0.41943
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 55s 140ms/step - accuracy: 0.9234 - dice_coefficient: 0.4678 - iou_metric: 0.8640 - loss: 0.9599 - val_accuracy: 0.9290 - val_dice_coefficient: 0.4165 - val_iou_metric: 0.8710 - val_loss: 0.9844 - learning_rate: 5.0000e-05
# Epoch 39/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9268 - dice_coefficient: 0.4711 - iou_metric: 0.8695 - loss: 0.9368
# Epoch 39: val_dice_coefficient improved from 0.41943 to 0.43138, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 58s 225ms/step - accuracy: 0.9268 - dice_coefficient: 0.4712 - iou_metric: 0.8695 - loss: 0.9368 - val_accuracy: 0.9370 - val_dice_coefficient: 0.4314 - val_iou_metric: 0.8846 - val_loss: 0.9682 - learning_rate: 5.0000e-05
# Epoch 40/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9288 - dice_coefficient: 0.4760 - iou_metric: 0.8729 - loss: 0.9265
# Epoch 40: val_dice_coefficient improved from 0.43138 to 0.43290, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 61s 286ms/step - accuracy: 0.9288 - dice_coefficient: 0.4760 - iou_metric: 0.8729 - loss: 0.9265 - val_accuracy: 0.9394 - val_dice_coefficient: 0.4329 - val_iou_metric: 0.8891 - val_loss: 0.9509 - learning_rate: 5.0000e-05
# Epoch 41/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9302 - dice_coefficient: 0.4862 - iou_metric: 0.8745 - loss: 0.9188
# Epoch 41: val_dice_coefficient improved from 0.43290 to 0.44214, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 50s 234ms/step - accuracy: 0.9302 - dice_coefficient: 0.4862 - iou_metric: 0.8745 - loss: 0.9188 - val_accuracy: 0.9445 - val_dice_coefficient: 0.4421 - val_iou_metric: 0.8978 - val_loss: 0.9348 - learning_rate: 5.0000e-05
# Epoch 42/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9303 - dice_coefficient: 0.4952 - iou_metric: 0.8745 - loss: 0.9085
# Epoch 42: val_dice_coefficient improved from 0.44214 to 0.45006, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 46s 217ms/step - accuracy: 0.9303 - dice_coefficient: 0.4952 - iou_metric: 0.8745 - loss: 0.9085 - val_accuracy: 0.9472 - val_dice_coefficient: 0.4501 - val_iou_metric: 0.9027 - val_loss: 0.9169 - learning_rate: 5.0000e-05
# Epoch 43/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9335 - dice_coefficient: 0.5034 - iou_metric: 0.8793 - loss: 0.8831
# Epoch 43: val_dice_coefficient improved from 0.45006 to 0.46288, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 51s 240ms/step - accuracy: 0.9335 - dice_coefficient: 0.5034 - iou_metric: 0.8793 - loss: 0.8831 - val_accuracy: 0.9466 - val_dice_coefficient: 0.4629 - val_iou_metric: 0.9016 - val_loss: 0.9009 - learning_rate: 5.0000e-05
# Epoch 44/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9329 - dice_coefficient: 0.5092 - iou_metric: 0.8789 - loss: 0.8770
# Epoch 44: val_dice_coefficient improved from 0.46288 to 0.46491, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 100s 326ms/step - accuracy: 0.9329 - dice_coefficient: 0.5092 - iou_metric: 0.8789 - loss: 0.8770 - val_accuracy: 0.9386 - val_dice_coefficient: 0.4649 - val_iou_metric: 0.8879 - val_loss: 0.9024 - learning_rate: 5.0000e-05
# Epoch 45/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9346 - dice_coefficient: 0.5083 - iou_metric: 0.8817 - loss: 0.8830
# Epoch 45: val_dice_coefficient improved from 0.46491 to 0.47846, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 49s 229ms/step - accuracy: 0.9346 - dice_coefficient: 0.5083 - iou_metric: 0.8817 - loss: 0.8830 - val_accuracy: 0.9429 - val_dice_coefficient: 0.4785 - val_iou_metric: 0.8947 - val_loss: 0.8776 - learning_rate: 5.0000e-05
# Epoch 46/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9327 - dice_coefficient: 0.5257 - iou_metric: 0.8782 - loss: 0.8635
# Epoch 46: val_dice_coefficient did not improve from 0.47846
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 141ms/step - accuracy: 0.9327 - dice_coefficient: 0.5256 - iou_metric: 0.8782 - loss: 0.8634 - val_accuracy: 0.9404 - val_dice_coefficient: 0.4775 - val_iou_metric: 0.8907 - val_loss: 0.8794 - learning_rate: 5.0000e-05
# Epoch 47/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9366 - dice_coefficient: 0.5336 - iou_metric: 0.8846 - loss: 0.8362
# Epoch 47: val_dice_coefficient improved from 0.47846 to 0.48448, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 51s 239ms/step - accuracy: 0.9366 - dice_coefficient: 0.5336 - iou_metric: 0.8846 - loss: 0.8362 - val_accuracy: 0.9427 - val_dice_coefficient: 0.4845 - val_iou_metric: 0.8948 - val_loss: 0.8749 - learning_rate: 5.0000e-05
# Epoch 48/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9376 - dice_coefficient: 0.5438 - iou_metric: 0.8863 - loss: 0.8184
# Epoch 48: val_dice_coefficient improved from 0.48448 to 0.48650, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 57s 267ms/step - accuracy: 0.9376 - dice_coefficient: 0.5438 - iou_metric: 0.8863 - loss: 0.8185 - val_accuracy: 0.9429 - val_dice_coefficient: 0.4865 - val_iou_metric: 0.8946 - val_loss: 0.8636 - learning_rate: 5.0000e-05
# Epoch 49/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9378 - dice_coefficient: 0.5474 - iou_metric: 0.8863 - loss: 0.8194
# Epoch 49: val_dice_coefficient improved from 0.48650 to 0.48947, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 53s 250ms/step - accuracy: 0.9378 - dice_coefficient: 0.5473 - iou_metric: 0.8863 - loss: 0.8193 - val_accuracy: 0.9467 - val_dice_coefficient: 0.4895 - val_iou_metric: 0.9014 - val_loss: 0.8601 - learning_rate: 5.0000e-05
# Epoch 50/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9387 - dice_coefficient: 0.5458 - iou_metric: 0.8882 - loss: 0.8182
# Epoch 50: val_dice_coefficient improved from 0.48947 to 0.49518, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 52s 243ms/step - accuracy: 0.9387 - dice_coefficient: 0.5458 - iou_metric: 0.8882 - loss: 0.8182 - val_accuracy: 0.9479 - val_dice_coefficient: 0.4952 - val_iou_metric: 0.9034 - val_loss: 0.8571 - learning_rate: 5.0000e-05
# Epoch 51/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9374 - dice_coefficient: 0.5469 - iou_metric: 0.8859 - loss: 0.8260
# Epoch 51: val_dice_coefficient did not improve from 0.49518
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 139ms/step - accuracy: 0.9374 - dice_coefficient: 0.5469 - iou_metric: 0.8859 - loss: 0.8260 - val_accuracy: 0.9426 - val_dice_coefficient: 0.4885 - val_iou_metric: 0.8937 - val_loss: 0.8700 - learning_rate: 5.0000e-05
# Epoch 52/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9397 - dice_coefficient: 0.5610 - iou_metric: 0.8897 - loss: 0.7982
# Epoch 52: val_dice_coefficient improved from 0.49518 to 0.49889, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 65s 308ms/step - accuracy: 0.9397 - dice_coefficient: 0.5610 - iou_metric: 0.8897 - loss: 0.7983 - val_accuracy: 0.9493 - val_dice_coefficient: 0.4989 - val_iou_metric: 0.9060 - val_loss: 0.8558 - learning_rate: 5.0000e-05
# Epoch 53/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9424 - dice_coefficient: 0.5559 - iou_metric: 0.8943 - loss: 0.7960
# Epoch 53: val_dice_coefficient did not improve from 0.49889
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 138ms/step - accuracy: 0.9424 - dice_coefficient: 0.5559 - iou_metric: 0.8943 - loss: 0.7960 - val_accuracy: 0.9462 - val_dice_coefficient: 0.4948 - val_iou_metric: 0.9001 - val_loss: 0.8577 - learning_rate: 5.0000e-05
# Epoch 54/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9417 - dice_coefficient: 0.5605 - iou_metric: 0.8932 - loss: 0.7860
# Epoch 54: val_dice_coefficient improved from 0.49889 to 0.50051, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 56s 262ms/step - accuracy: 0.9417 - dice_coefficient: 0.5605 - iou_metric: 0.8932 - loss: 0.7860 - val_accuracy: 0.9481 - val_dice_coefficient: 0.5005 - val_iou_metric: 0.9039 - val_loss: 0.8546 - learning_rate: 5.0000e-05
# Epoch 55/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9400 - dice_coefficient: 0.5741 - iou_metric: 0.8903 - loss: 0.7729
# Epoch 55: val_dice_coefficient improved from 0.50051 to 0.50673, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 88s 290ms/step - accuracy: 0.9400 - dice_coefficient: 0.5741 - iou_metric: 0.8903 - loss: 0.7729 - val_accuracy: 0.9535 - val_dice_coefficient: 0.5067 - val_iou_metric: 0.9132 - val_loss: 0.8469 - learning_rate: 5.0000e-05
# Epoch 56/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9434 - dice_coefficient: 0.5803 - iou_metric: 0.8960 - loss: 0.7567
# Epoch 56: val_dice_coefficient did not improve from 0.50673
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 51s 141ms/step - accuracy: 0.9434 - dice_coefficient: 0.5802 - iou_metric: 0.8960 - loss: 0.7568 - val_accuracy: 0.9486 - val_dice_coefficient: 0.5016 - val_iou_metric: 0.9044 - val_loss: 0.8451 - learning_rate: 5.0000e-05
# Epoch 57/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9425 - dice_coefficient: 0.5684 - iou_metric: 0.8943 - loss: 0.7872
# Epoch 57: val_dice_coefficient did not improve from 0.50673
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 137ms/step - accuracy: 0.9425 - dice_coefficient: 0.5684 - iou_metric: 0.8943 - loss: 0.7871 - val_accuracy: 0.9493 - val_dice_coefficient: 0.5041 - val_iou_metric: 0.9061 - val_loss: 0.8435 - learning_rate: 5.0000e-05
# Epoch 58/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9426 - dice_coefficient: 0.5767 - iou_metric: 0.8948 - loss: 0.7651
# Epoch 58: val_dice_coefficient improved from 0.50673 to 0.50683, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 69s 328ms/step - accuracy: 0.9426 - dice_coefficient: 0.5767 - iou_metric: 0.8948 - loss: 0.7650 - val_accuracy: 0.9508 - val_dice_coefficient: 0.5068 - val_iou_metric: 0.9082 - val_loss: 0.8332 - learning_rate: 5.0000e-05
# Epoch 59/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9456 - dice_coefficient: 0.5872 - iou_metric: 0.8998 - loss: 0.7410
# Epoch 59: val_dice_coefficient improved from 0.50683 to 0.51333, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 71s 276ms/step - accuracy: 0.9456 - dice_coefficient: 0.5872 - iou_metric: 0.8998 - loss: 0.7410 - val_accuracy: 0.9531 - val_dice_coefficient: 0.5133 - val_iou_metric: 0.9121 - val_loss: 0.8267 - learning_rate: 5.0000e-05
# Epoch 60/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9462 - dice_coefficient: 0.5932 - iou_metric: 0.9009 - loss: 0.7222
# Epoch 60: val_dice_coefficient did not improve from 0.51333
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 140ms/step - accuracy: 0.9462 - dice_coefficient: 0.5932 - iou_metric: 0.9009 - loss: 0.7222 - val_accuracy: 0.9518 - val_dice_coefficient: 0.5124 - val_iou_metric: 0.9100 - val_loss: 0.8248 - learning_rate: 5.0000e-05
# Epoch 61/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9427 - dice_coefficient: 0.5814 - iou_metric: 0.8952 - loss: 0.7603
# Epoch 61: val_dice_coefficient did not improve from 0.51333
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 139ms/step - accuracy: 0.9427 - dice_coefficient: 0.5814 - iou_metric: 0.8952 - loss: 0.7603 - val_accuracy: 0.9521 - val_dice_coefficient: 0.5123 - val_iou_metric: 0.9106 - val_loss: 0.8322 - learning_rate: 5.0000e-05
# Epoch 62/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9432 - dice_coefficient: 0.5847 - iou_metric: 0.8958 - loss: 0.7486
# Epoch 62: val_dice_coefficient did not improve from 0.51333
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 40s 137ms/step - accuracy: 0.9432 - dice_coefficient: 0.5847 - iou_metric: 0.8958 - loss: 0.7486 - val_accuracy: 0.9510 - val_dice_coefficient: 0.5114 - val_iou_metric: 0.9085 - val_loss: 0.8277 - learning_rate: 5.0000e-05
# Epoch 63/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9434 - dice_coefficient: 0.5822 - iou_metric: 0.8961 - loss: 0.7562
# Epoch 63: val_dice_coefficient did not improve from 0.51333
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 139ms/step - accuracy: 0.9434 - dice_coefficient: 0.5822 - iou_metric: 0.8961 - loss: 0.7561 - val_accuracy: 0.9517 - val_dice_coefficient: 0.5119 - val_iou_metric: 0.9101 - val_loss: 0.8286 - learning_rate: 5.0000e-05
# Epoch 64/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9425 - dice_coefficient: 0.5860 - iou_metric: 0.8950 - loss: 0.7541
# Epoch 64: val_dice_coefficient improved from 0.51333 to 0.51476, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 76s 307ms/step - accuracy: 0.9426 - dice_coefficient: 0.5860 - iou_metric: 0.8951 - loss: 0.7540 - val_accuracy: 0.9509 - val_dice_coefficient: 0.5148 - val_iou_metric: 0.9085 - val_loss: 0.8218 - learning_rate: 5.0000e-05
# Epoch 65/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9460 - dice_coefficient: 0.5915 - iou_metric: 0.9005 - loss: 0.7338
# Epoch 65: val_dice_coefficient improved from 0.51476 to 0.51822, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 54s 254ms/step - accuracy: 0.9460 - dice_coefficient: 0.5915 - iou_metric: 0.9005 - loss: 0.7338 - val_accuracy: 0.9532 - val_dice_coefficient: 0.5182 - val_iou_metric: 0.9123 - val_loss: 0.8136 - learning_rate: 5.0000e-05
# Epoch 66/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9438 - dice_coefficient: 0.5991 - iou_metric: 0.8975 - loss: 0.7294
# Epoch 66: val_dice_coefficient did not improve from 0.51822
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 138ms/step - accuracy: 0.9438 - dice_coefficient: 0.5990 - iou_metric: 0.8975 - loss: 0.7295 - val_accuracy: 0.9482 - val_dice_coefficient: 0.5073 - val_iou_metric: 0.9046 - val_loss: 0.8569 - learning_rate: 5.0000e-05
# Epoch 67/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9460 - dice_coefficient: 0.5963 - iou_metric: 0.9005 - loss: 0.7252
# Epoch 67: val_dice_coefficient improved from 0.51822 to 0.52117, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 61s 290ms/step - accuracy: 0.9460 - dice_coefficient: 0.5963 - iou_metric: 0.9005 - loss: 0.7252 - val_accuracy: 0.9554 - val_dice_coefficient: 0.5212 - val_iou_metric: 0.9165 - val_loss: 0.8143 - learning_rate: 5.0000e-05
# Epoch 68/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9459 - dice_coefficient: 0.5921 - iou_metric: 0.9007 - loss: 0.7393
# Epoch 68: val_dice_coefficient improved from 0.52117 to 0.52248, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 59s 278ms/step - accuracy: 0.9459 - dice_coefficient: 0.5921 - iou_metric: 0.9007 - loss: 0.7393 - val_accuracy: 0.9536 - val_dice_coefficient: 0.5225 - val_iou_metric: 0.9131 - val_loss: 0.8113 - learning_rate: 5.0000e-05
# Epoch 69/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9470 - dice_coefficient: 0.6024 - iou_metric: 0.9021 - loss: 0.7127
# Epoch 69: val_dice_coefficient did not improve from 0.52248
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 30s 139ms/step - accuracy: 0.9470 - dice_coefficient: 0.6024 - iou_metric: 0.9021 - loss: 0.7127 - val_accuracy: 0.9538 - val_dice_coefficient: 0.5215 - val_iou_metric: 0.9136 - val_loss: 0.8086 - learning_rate: 5.0000e-05
# Epoch 70/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9491 - dice_coefficient: 0.5941 - iou_metric: 0.9056 - loss: 0.7202
# ...
# Epoch 119/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9570 - dice_coefficient: 0.7136 - iou_metric: 0.9196 - loss: 0.5346
# Epoch 119: val_dice_coefficient did not improve from 0.59304
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 88s 145ms/step - accuracy: 0.9570 - dice_coefficient: 0.7136 - iou_metric: 0.9196 - loss: 0.5346 - val_accuracy: 0.9591 - val_dice_coefficient: 0.5895 - val_iou_metric: 0.9233 - val_loss: 0.7194 - learning_rate: 5.0000e-05
# Epoch 120/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9577 - dice_coefficient: 0.7030 - iou_metric: 0.9209 - loss: 0.5507
# Epoch 120: val_dice_coefficient did not improve from 0.59304
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 41s 143ms/step - accuracy: 0.9577 - dice_coefficient: 0.7030 - iou_metric: 0.9209 - loss: 0.5507 - val_accuracy: 0.9613 - val_dice_coefficient: 0.5924 - val_iou_metric: 0.9275 - val_loss: 0.7185 - learning_rate: 5.0000e-05
# Epoch 121/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9566 - dice_coefficient: 0.6994 - iou_metric: 0.9188 - loss: 0.5469
# Epoch 121: val_dice_coefficient did not improve from 0.59304
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 145ms/step - accuracy: 0.9566 - dice_coefficient: 0.6994 - iou_metric: 0.9188 - loss: 0.5469 - val_accuracy: 0.9613 - val_dice_coefficient: 0.5928 - val_iou_metric: 0.9274 - val_loss: 0.7208 - learning_rate: 5.0000e-05
# Epoch 122/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9577 - dice_coefficient: 0.7174 - iou_metric: 0.9208 - loss: 0.5279
# Epoch 122: val_dice_coefficient improved from 0.59304 to 0.59540, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 115s 500ms/step - accuracy: 0.9577 - dice_coefficient: 0.7173 - iou_metric: 0.9208 - loss: 0.5280 - val_accuracy: 0.9610 - val_dice_coefficient: 0.5954 - val_iou_metric: 0.9268 - val_loss: 0.7128 - learning_rate: 5.0000e-05
# Epoch 123/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9565 - dice_coefficient: 0.7024 - iou_metric: 0.9187 - loss: 0.5487
# Epoch 123: val_dice_coefficient did not improve from 0.59540
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 68s 144ms/step - accuracy: 0.9565 - dice_coefficient: 0.7024 - iou_metric: 0.9187 - loss: 0.5486 - val_accuracy: 0.9628 - val_dice_coefficient: 0.5903 - val_iou_metric: 0.9301 - val_loss: 0.7286 - learning_rate: 5.0000e-05
# Epoch 124/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9589 - dice_coefficient: 0.7154 - iou_metric: 0.9229 - loss: 0.5191
# Epoch 124: val_dice_coefficient improved from 0.59540 to 0.59673, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 96s 411ms/step - accuracy: 0.9589 - dice_coefficient: 0.7153 - iou_metric: 0.9229 - loss: 0.5192 - val_accuracy: 0.9588 - val_dice_coefficient: 0.5967 - val_iou_metric: 0.9226 - val_loss: 0.7075 - learning_rate: 5.0000e-05
# Epoch 125/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9565 - dice_coefficient: 0.7054 - iou_metric: 0.9189 - loss: 0.5463
# Epoch 125: val_dice_coefficient improved from 0.59673 to 0.59698, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 90s 425ms/step - accuracy: 0.9565 - dice_coefficient: 0.7054 - iou_metric: 0.9189 - loss: 0.5463 - val_accuracy: 0.9609 - val_dice_coefficient: 0.5970 - val_iou_metric: 0.9270 - val_loss: 0.7263 - learning_rate: 5.0000e-05
# Epoch 126/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9583 - dice_coefficient: 0.6981 - iou_metric: 0.9221 - loss: 0.5550
# Epoch 126: val_dice_coefficient did not improve from 0.59698
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 144ms/step - accuracy: 0.9583 - dice_coefficient: 0.6981 - iou_metric: 0.9221 - loss: 0.5549 - val_accuracy: 0.9599 - val_dice_coefficient: 0.5919 - val_iou_metric: 0.9250 - val_loss: 0.7345 - learning_rate: 5.0000e-05
# Epoch 127/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9595 - dice_coefficient: 0.7224 - iou_metric: 0.9239 - loss: 0.5084
# Epoch 127: val_dice_coefficient improved from 0.59698 to 0.59977, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 86s 406ms/step - accuracy: 0.9595 - dice_coefficient: 0.7224 - iou_metric: 0.9239 - loss: 0.5085 - val_accuracy: 0.9613 - val_dice_coefficient: 0.5998 - val_iou_metric: 0.9273 - val_loss: 0.7140 - learning_rate: 5.0000e-05
# Epoch 128/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9587 - dice_coefficient: 0.7160 - iou_metric: 0.9225 - loss: 0.5164
# Epoch 128: val_dice_coefficient did not improve from 0.59977
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 144ms/step - accuracy: 0.9587 - dice_coefficient: 0.7160 - iou_metric: 0.9225 - loss: 0.5164 - val_accuracy: 0.9607 - val_dice_coefficient: 0.5957 - val_iou_metric: 0.9261 - val_loss: 0.7159 - learning_rate: 5.0000e-05
# Epoch 129/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9574 - dice_coefficient: 0.7228 - iou_metric: 0.9202 - loss: 0.5161
# Epoch 129: val_dice_coefficient did not improve from 0.59977
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 42s 148ms/step - accuracy: 0.9574 - dice_coefficient: 0.7227 - iou_metric: 0.9202 - loss: 0.5162 - val_accuracy: 0.9552 - val_dice_coefficient: 0.5864 - val_iou_metric: 0.9187 - val_loss: 0.7839 - learning_rate: 5.0000e-05
# Epoch 130/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9560 - dice_coefficient: 0.7088 - iou_metric: 0.9180 - loss: 0.5393
# Epoch 130: val_dice_coefficient did not improve from 0.59977
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 40s 145ms/step - accuracy: 0.9560 - dice_coefficient: 0.7088 - iou_metric: 0.9180 - loss: 0.5393 - val_accuracy: 0.9606 - val_dice_coefficient: 0.5937 - val_iou_metric: 0.9258 - val_loss: 0.7218 - learning_rate: 5.0000e-05
# Epoch 131/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9582 - dice_coefficient: 0.7069 - iou_metric: 0.9217 - loss: 0.5381
# Epoch 131: val_dice_coefficient did not improve from 0.59977
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 41s 144ms/step - accuracy: 0.9582 - dice_coefficient: 0.7069 - iou_metric: 0.9217 - loss: 0.5380 - val_accuracy: 0.9628 - val_dice_coefficient: 0.5984 - val_iou_metric: 0.9295 - val_loss: 0.7112 - learning_rate: 5.0000e-05
# Epoch 132/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9595 - dice_coefficient: 0.7170 - iou_metric: 0.9240 - loss: 0.5170
# Epoch 132: val_dice_coefficient did not improve from 0.59977
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 145ms/step - accuracy: 0.9595 - dice_coefficient: 0.7169 - iou_metric: 0.9240 - loss: 0.5171 - val_accuracy: 0.9603 - val_dice_coefficient: 0.5987 - val_iou_metric: 0.9254 - val_loss: 0.7115 - learning_rate: 5.0000e-05
# Epoch 133/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9582 - dice_coefficient: 0.7106 - iou_metric: 0.9217 - loss: 0.5301
# Epoch 133: val_dice_coefficient improved from 0.59977 to 0.60258, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 102s 436ms/step - accuracy: 0.9582 - dice_coefficient: 0.7106 - iou_metric: 0.9217 - loss: 0.5301 - val_accuracy: 0.9638 - val_dice_coefficient: 0.6026 - val_iou_metric: 0.9317 - val_loss: 0.7089 - learning_rate: 5.0000e-05
# Epoch 134/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9608 - dice_coefficient: 0.7201 - iou_metric: 0.9263 - loss: 0.5104
# Epoch 134: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 81s 147ms/step - accuracy: 0.9608 - dice_coefficient: 0.7202 - iou_metric: 0.9262 - loss: 0.5104 - val_accuracy: 0.9615 - val_dice_coefficient: 0.6013 - val_iou_metric: 0.9282 - val_loss: 0.7325 - learning_rate: 5.0000e-05
# Epoch 135/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9605 - dice_coefficient: 0.7271 - iou_metric: 0.9258 - loss: 0.5016
# Epoch 135: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 144ms/step - accuracy: 0.9605 - dice_coefficient: 0.7271 - iou_metric: 0.9258 - loss: 0.5017 - val_accuracy: 0.9605 - val_dice_coefficient: 0.5974 - val_iou_metric: 0.9265 - val_loss: 0.7366 - learning_rate: 5.0000e-05
# Epoch 136/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9579 - dice_coefficient: 0.7147 - iou_metric: 0.9212 - loss: 0.5199
# Epoch 136: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 41s 145ms/step - accuracy: 0.9579 - dice_coefficient: 0.7147 - iou_metric: 0.9212 - loss: 0.5199 - val_accuracy: 0.9587 - val_dice_coefficient: 0.5955 - val_iou_metric: 0.9231 - val_loss: 0.7247 - learning_rate: 5.0000e-05
# Epoch 137/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9585 - dice_coefficient: 0.7143 - iou_metric: 0.9224 - loss: 0.5256
# Epoch 137: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 144ms/step - accuracy: 0.9586 - dice_coefficient: 0.7144 - iou_metric: 0.9224 - loss: 0.5255 - val_accuracy: 0.9612 - val_dice_coefficient: 0.5961 - val_iou_metric: 0.9274 - val_loss: 0.7239 - learning_rate: 5.0000e-05
# Epoch 138/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9596 - dice_coefficient: 0.7246 - iou_metric: 0.9244 - loss: 0.5054
# Epoch 138: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 42s 150ms/step - accuracy: 0.9596 - dice_coefficient: 0.7246 - iou_metric: 0.9244 - loss: 0.5054 - val_accuracy: 0.9605 - val_dice_coefficient: 0.5913 - val_iou_metric: 0.9262 - val_loss: 0.7331 - learning_rate: 5.0000e-05
# Epoch 139/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9595 - dice_coefficient: 0.7081 - iou_metric: 0.9240 - loss: 0.5314
# Epoch 139: val_dice_coefficient did not improve from 0.60258
#
# Epoch 139: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 144ms/step - accuracy: 0.9595 - dice_coefficient: 0.7081 - iou_metric: 0.9240 - loss: 0.5313 - val_accuracy: 0.9607 - val_dice_coefficient: 0.5989 - val_iou_metric: 0.9263 - val_loss: 0.7139 - learning_rate: 5.0000e-05
# Epoch 140/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9600 - dice_coefficient: 0.7248 - iou_metric: 0.9247 - loss: 0.5037
# Epoch 140: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.9600 - dice_coefficient: 0.7248 - iou_metric: 0.9247 - loss: 0.5038 - val_accuracy: 0.9605 - val_dice_coefficient: 0.5955 - val_iou_metric: 0.9264 - val_loss: 0.7291 - learning_rate: 2.5000e-05
# Epoch 141/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9596 - dice_coefficient: 0.7183 - iou_metric: 0.9242 - loss: 0.5109
# Epoch 141: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 41s 145ms/step - accuracy: 0.9596 - dice_coefficient: 0.7183 - iou_metric: 0.9242 - loss: 0.5109 - val_accuracy: 0.9615 - val_dice_coefficient: 0.5978 - val_iou_metric: 0.9279 - val_loss: 0.7183 - learning_rate: 2.5000e-05
# Epoch 142/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9606 - dice_coefficient: 0.7319 - iou_metric: 0.9258 - loss: 0.4911
# Epoch 142: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 146ms/step - accuracy: 0.9605 - dice_coefficient: 0.7318 - iou_metric: 0.9258 - loss: 0.4912 - val_accuracy: 0.9616 - val_dice_coefficient: 0.6000 - val_iou_metric: 0.9279 - val_loss: 0.7104 - learning_rate: 2.5000e-05
# Epoch 143/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9597 - dice_coefficient: 0.7307 - iou_metric: 0.9244 - loss: 0.4888
# Epoch 143: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 41s 145ms/step - accuracy: 0.9597 - dice_coefficient: 0.7307 - iou_metric: 0.9244 - loss: 0.4888 - val_accuracy: 0.9617 - val_dice_coefficient: 0.5974 - val_iou_metric: 0.9282 - val_loss: 0.7201 - learning_rate: 2.5000e-05
# Epoch 144/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9586 - dice_coefficient: 0.7362 - iou_metric: 0.9224 - loss: 0.4845
# Epoch 144: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 41s 145ms/step - accuracy: 0.9586 - dice_coefficient: 0.7361 - iou_metric: 0.9224 - loss: 0.4845 - val_accuracy: 0.9614 - val_dice_coefficient: 0.5975 - val_iou_metric: 0.9277 - val_loss: 0.7203 - learning_rate: 2.5000e-05
# Epoch 145/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9598 - dice_coefficient: 0.7263 - iou_metric: 0.9246 - loss: 0.5026
# Epoch 145: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 146ms/step - accuracy: 0.9598 - dice_coefficient: 0.7263 - iou_metric: 0.9246 - loss: 0.5026 - val_accuracy: 0.9615 - val_dice_coefficient: 0.5984 - val_iou_metric: 0.9278 - val_loss: 0.7183 - learning_rate: 2.5000e-05
# Epoch 146/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9595 - dice_coefficient: 0.7192 - iou_metric: 0.9241 - loss: 0.5083
# Epoch 146: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 41s 144ms/step - accuracy: 0.9595 - dice_coefficient: 0.7192 - iou_metric: 0.9241 - loss: 0.5083 - val_accuracy: 0.9617 - val_dice_coefficient: 0.5989 - val_iou_metric: 0.9283 - val_loss: 0.7221 - learning_rate: 2.5000e-05
# Epoch 147/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9601 - dice_coefficient: 0.7315 - iou_metric: 0.9250 - loss: 0.4905
# Epoch 147: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 41s 144ms/step - accuracy: 0.9601 - dice_coefficient: 0.7314 - iou_metric: 0.9250 - loss: 0.4906 - val_accuracy: 0.9624 - val_dice_coefficient: 0.5984 - val_iou_metric: 0.9295 - val_loss: 0.7180 - learning_rate: 2.5000e-05
# Epoch 148/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9605 - dice_coefficient: 0.7295 - iou_metric: 0.9257 - loss: 0.4918
# Epoch 148: val_dice_coefficient did not improve from 0.60258
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 31s 143ms/step - accuracy: 0.9605 - dice_coefficient: 0.7295 - iou_metric: 0.9257 - loss: 0.4918 - val_accuracy: 0.9620 - val_dice_coefficient: 0.6001 - val_iou_metric: 0.9288 - val_loss: 0.7188 - learning_rate: 2.5000e-05
# Epoch 149/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9588 - dice_coefficient: 0.7269 - iou_metric: 0.9226 - loss: 0.4983
# Epoch 149: val_dice_coefficient improved from 0.60258 to 0.60421, saving model to efficient_v2s_weed_model.keras
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 90s 425ms/step - accuracy: 0.9588 - dice_coefficient: 0.7270 - iou_metric: 0.9227 - loss: 0.4982 - val_accuracy: 0.9614 - val_dice_coefficient: 0.6042 - val_iou_metric: 0.9277 - val_loss: 0.7063 - learning_rate: 2.5000e-05
# Epoch 150/150
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9597 - dice_coefficient: 0.7341 - iou_metric: 0.9243 - loss: 0.4927
# Epoch 150: val_dice_coefficient did not improve from 0.60421
# 210/210 ━━━━━━━━━━━━━━━━━━━━ 84s 146ms/step - accuracy: 0.9597 - dice_coefficient: 0.7341 - iou_metric: 0.9243 - loss: 0.4927 - val_accuracy: 0.9611 - val_dice_coefficient: 0.5969 - val_iou_metric: 0.9272 - val_loss: 0.7187 - learning_rate: 2.5000e-05
# Restoring model weights from the end of the best epoch: 149.
# Visualizando predicciones...
# Visualizing 4 samples from the validation set...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 14s 14s/step
# ¡Entrenamiento completado! El mejor modelo se guardó como 'efficient_v2s_weed_model.keras'
# Evaluando el modelo final en el conjunto de validación:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9618 - dice_coefficient: 0.6024 - iou_metric: 0.9281 - loss: 0.7298
# Validation Loss: 0.7063
# Validation Dice Coefficient: 0.6042
# Validation IoU: 0.9277
# Validation Accuracy: 0.9614
# Calculando IoU por clase...
#
# --- IoU por Clase (EfficientNetV2S) ---
# IoU for Background: 0.9509
# IoU for Cow-tongue: 0.9092
# IoU for Dandelion: 0.8952
# IoU for Kikuyo: 0.8849
# IoU for Other: 0.6382
# IoU for Potato: 0.8890
#
# Promedio IoU por clase: 0.8612
# Modelo guardado como: efficient_v2s_weed_model.keras
# Log de entrenamiento guardado como: training_log_v2s.csv
