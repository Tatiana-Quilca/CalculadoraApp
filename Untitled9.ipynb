# %% [markdown]
# <a href="https://colab.research.google.com/github/Tatiana-Quilca/CalculadoraApp/blob/master/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Paso 1: Descomprimir el dataset (esto solo se hace una vez)
import os
import zipfile

zip_path = '/content/Balanced.zip'
extract_path = '/content/'

# Solo descomprimir si no se ha hecho antes
if not os.path.exists(os.path.join(extract_path, 'Balanced')):
    print(f"Descomprimiendo {zip_path}...")
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    print("¡Descompresión completada!")
else:
    print("La carpeta 'Balanced' ya existe. Omitiendo descompresión.")
# Out:
# Descomprimiendo /content/Balanced.zip...
# ¡Descompresión completada!

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
import numpy as np
import matplotlib.pyplot as plt
import os
from glob import glob

# --- Configuración del modelo ---
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6  # 0-background, 1-Cow-tongue, 2-Dandelion, 3-Kikuyo, 4-Other, 5-Potato
BATCH_SIZE = 16
EPOCHS = 50
LEARNING_RATE = 1e-4

# --- Paths ---
BASE_PATH = '/content/Balanced'
TRAIN_IMAGES_PATH = os.path.join(BASE_PATH, 'train/images')
TRAIN_MASKS_PATH = os.path.join(BASE_PATH, 'train/masks')
VAL_IMAGES_PATH = os.path.join(BASE_PATH, 'val/images')
VAL_MASKS_PATH = os.path.join(BASE_PATH, 'val/masks')

# --- Módulos del modelo ---
class ASPPModule(layers.Layer):
    """Atrous Spatial Pyramid Pooling Module optimizado"""
    def __init__(self, filters=64, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters

        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1 = layers.BatchNormalization()

        self.conv_3x3_6 = layers.Conv2D(filters, 3, padding='same', dilation_rate=6, use_bias=False)
        self.bn_3x3_6 = layers.BatchNormalization()

        self.conv_3x3_12 = layers.Conv2D(filters, 3, padding='same', dilation_rate=12, use_bias=False)
        self.bn_3x3_12 = layers.BatchNormalization()

        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_1x1_gap = layers.BatchNormalization()

        self.conv_final = layers.Conv2D(filters, 1, padding='same', use_bias=False)
        self.bn_final = layers.BatchNormalization()
        self.dropout = layers.Dropout(0.1)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)

        conv_1x1 = self.bn_1x1(self.conv_1x1(inputs), training=training)
        conv_3x3_6 = self.bn_3x3_6(self.conv_3x3_6(inputs), training=training)
        conv_3x3_12 = self.bn_3x3_12(self.conv_3x3_12(inputs), training=training)

        gap = self.global_avg_pool(inputs)
        gap = self.bn_1x1_gap(self.conv_1x1_gap(gap), training=training)
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]], method='bilinear')

        concat = layers.Concatenate()([conv_1x1, conv_3x3_6, conv_3x3_12, gap])

        output = self.bn_final(self.conv_final(concat), training=training)
        output = self.dropout(output, training=training)

        return output

class DeformableAttention(layers.Layer):
    """Simplified Deformable Attention Layer"""
    def __init__(self, filters, **kwargs):
        super(DeformableAttention, self).__init__(**kwargs)
        self.filters = filters

    def build(self, input_shape):
        self.attention_conv = layers.Conv2D(self.filters, 1, padding='same', activation='sigmoid', name='attention_weights_conv', use_bias=False)
        self.bn_attention = layers.BatchNormalization()

        self.feature_conv = layers.Conv2D(self.filters, 3, padding='same', activation='relu', name='feature_processing_conv', use_bias=False)
        self.bn_feature = layers.BatchNormalization()

        super(DeformableAttention, self).build(input_shape)

    def call(self, inputs, training=None):
        attention_weights = self.bn_attention(self.attention_conv(inputs), training=training)
        features = self.bn_feature(self.feature_conv(inputs), training=training)
        attended_features = features * attention_weights
        return attended_features

def create_efficient_backbone(input_shape):
    """Create EfficientNetV2-B0 backbone for feature extraction"""
    base_model = tf.keras.applications.EfficientNetV2B0(
        input_shape=input_shape,
        weights=None,  # No cargar pesos preentrenados
        include_top=False
    )

    layer_names = [
        'block1a_project_activation',
        'block2a_expand_activation',
        'block3a_expand_activation',
        'block4a_expand_activation',
        'top_activation'
    ]

    outputs = [base_model.get_layer(name).output for name in layer_names]

    return Model(inputs=base_model.input, outputs=outputs, name='EfficientNetV2B0_Backbone')

def create_weed_detection_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    """Create the complete weed detection (segmentation) model"""
    inputs = layers.Input(shape=input_shape)

    backbone = create_efficient_backbone(input_shape)
    backbone_features = backbone(inputs)

    deep_features = backbone_features[-1]
    mid_features = backbone_features[-3]

    aspp_features = ASPPModule(filters=64)(deep_features)
    attended_features = DeformableAttention(filters=64)(aspp_features)

    decoder_features = layers.Conv2DTranspose(64, 2, strides=2, padding='same', use_bias=False)(attended_features)
    decoder_features = layers.BatchNormalization()(decoder_features)
    decoder_features = layers.Conv2DTranspose(64, 2, strides=2, padding='same', use_bias=False)(decoder_features)
    decoder_features = layers.BatchNormalization()(decoder_features)

    mid_processed = layers.Conv2D(32, 1, padding='same', use_bias=False)(mid_features)
    mid_processed = layers.BatchNormalization()(mid_processed)

    decoder_concat = layers.Concatenate()([decoder_features, mid_processed])

    decoder_conv1 = layers.Conv2D(64, 3, padding='same', use_bias=False)(decoder_concat)
    decoder_conv1 = layers.BatchNormalization()(decoder_conv1)
    decoder_conv2 = layers.Conv2D(64, 3, padding='same', use_bias=False)(decoder_conv1)
    decoder_conv2 = layers.BatchNormalization()(decoder_conv2)

    final_upsample = layers.Conv2DTranspose(num_classes, 2, strides=2, padding='same', use_bias=False)(decoder_conv2)
    final_upsample = layers.BatchNormalization()(final_upsample)
    final_upsample = layers.Conv2DTranspose(num_classes, 2, strides=2, padding='same', use_bias=False)(final_upsample)
    final_upsample = layers.BatchNormalization()(final_upsample)
    final_upsample = layers.Conv2DTranspose(num_classes, 2, strides=2, padding='same', use_bias=False)(final_upsample)
    final_upsample = layers.BatchNormalization()(final_upsample)

    outputs = layers.Conv2D(num_classes, 1, padding='same', activation='softmax', name='segmentation_output')(final_upsample)

    model = Model(inputs=inputs, outputs=outputs, name='WeedDetectionModel')

    return model

# --- Métricas y Funciones de Pérdida ---
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    """Dice coefficient for multiclass segmentation, averaged over classes"""
    y_true_f = tf.reshape(y_true, [-1, NUM_CLASSES])
    y_pred_f = tf.reshape(y_pred, [-1, NUM_CLASSES])

    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
    dice_scores = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f, axis=0) + tf.reduce_sum(y_pred_f, axis=0) + smooth)

    return tf.reduce_mean(dice_scores)

def dice_loss(y_true, y_pred):
    """Dice loss function (1 - Dice Coefficient)"""
    return 1 - dice_coefficient(y_true, y_pred)

def combined_loss(y_true, y_pred):
    """Combined loss: Categorical Crossentropy + Dice Loss"""
    ce_loss = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    d_loss = dice_loss(y_true, y_pred)
    return ce_loss + d_loss

def iou_metric(y_true, y_pred):
    """IoU (Intersection over Union) metric for multiclass segmentation, averaged over classes"""
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3]) - intersection

    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou)

def iou_per_class(y_true, y_pred):
    """IoU (Intersection over Union) metric for multiclass segmentation, per class"""
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    y_pred = tf.one_hot(tf.argmax(y_pred, axis=-1), depth=NUM_CLASSES)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])
    union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2]) - intersection

    iou = tf.where(tf.equal(union, 0), 1.0, intersection / union)
    return tf.reduce_mean(iou, axis=0)  # Average over batch dimension

# --- Carga y Preprocesamiento de Datos ---
def load_and_preprocess_data(images_path, masks_path):
    """Load and preprocess the dataset from specified paths"""
    def load_image(image_path):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_image(image, channels=3, expand_animations=False)
        image.set_shape([None, None, 3])
        image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
        image = tf.cast(image, tf.float32) / 255.0
        return image

    def load_mask(mask_path):
        mask = tf.io.read_file(mask_path)
        mask = tf.image.decode_png(mask, channels=1)
        mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH], method='nearest')
        mask = tf.cast(mask, tf.int32)
        mask = tf.squeeze(mask, axis=-1)
        mask = tf.one_hot(mask, NUM_CLASSES)
        return mask

    image_paths = sorted(glob(os.path.join(images_path, '*.jpg')))
    mask_paths = sorted(glob(os.path.join(masks_path, '*.png')))

    if not image_paths:
        raise FileNotFoundError(f"No image files found in: {images_path}. Check path and file extensions.")
    if not mask_paths:
        raise FileNotFoundError(f"No mask files found in: {masks_path}. Check path and file extensions.")

    if len(image_paths) != len(mask_paths):
        print(f"DEBUG: Found {len(image_paths)} images and {len(mask_paths)} masks.")
        print("DEBUG: First 5 image files:", [os.path.basename(p) for p in image_paths[:5]])
        print("DEBUG: First 5 mask files:", [os.path.basename(p) for p in mask_paths[:5]])
        raise ValueError("Number of images and masks do not match. Check filenames and ensure a 1-to-1 correspondence.")

    print(f"Found {len(image_paths)} images and {len(mask_paths)} masks")

    image_ds = tf.data.Dataset.from_tensor_slices(image_paths).map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
    mask_ds = tf.data.Dataset.from_tensor_slices(mask_paths).map(load_mask, num_parallel_calls=tf.data.AUTOTUNE)

    dataset = tf.data.Dataset.zip((image_ds, mask_ds))

    return dataset

def augment_data(image, mask):
    """Data augmentation"""
    if tf.random.uniform([]) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform([]) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    if tf.random.uniform([]) > 0.5:
        k = tf.random.uniform([], maxval=4, dtype=tf.int32)
        image = tf.image.rot90(image, k)
        mask = tf.image.rot90(mask, k)

    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, lower=0.8, upper=1.2)

    image = tf.clip_by_value(image, 0.0, 1.0)

    return image, mask

def create_datasets(validation_split=0.2):
    """Create training and validation datasets with augmentation and batching"""
    train_dataset = load_and_preprocess_data(TRAIN_IMAGES_PATH, TRAIN_MASKS_PATH)
    val_dataset = load_and_preprocess_data(VAL_IMAGES_PATH, VAL_MASKS_PATH)

    train_dataset = train_dataset.shuffle(buffer_size=1000)
    val_dataset = val_dataset.shuffle(buffer_size=1000)

    train_dataset = train_dataset.map(augment_data, num_parallel_calls=tf.data.AUTOTUNE)
    train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    val_dataset = val_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    print(f"Training batches (approx): {len(list(train_dataset)) if tf.data.experimental.cardinality(train_dataset) != tf.data.experimental.INFINITE_CARDINALITY else 'unknown'}")
    print(f"Validation batches (approx): {len(list(val_dataset)) if tf.data.experimental.cardinality(val_dataset) != tf.data.experimental.INFINITE_CARDINALITY else 'unknown'}")

    return train_dataset, val_dataset

def train_model(train_dataset, val_dataset, model_save_path='best_weed_model.h5'):
    """Train the weed detection model with specified callbacks"""
    model = create_weed_detection_model()
    model.summary()

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss=combined_loss,
        metrics=[dice_coefficient, iou_metric, 'accuracy']
    )

    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            model_save_path,
            monitor='val_dice_coefficient',
            save_best_only=True,
            mode='max',
            verbose=1
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_dice_coefficient',
            patience=20,
            mode='max',
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=10,
            min_lr=1e-7,
            verbose=1
        )
    ]

    print(f"Starting training for {EPOCHS} epochs...")
    history = model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=callbacks,
        verbose=1
    )

    return model, history

def visualize_predictions(model, val_dataset, num_samples=4):
    """Visualize original images, true masks, and predicted masks"""
    class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']

    print(f"Visualizing {num_samples} samples from the validation set...")

    for images, masks in val_dataset.take(1):
        predictions = model.predict(images)

        fig, axes = plt.subplots(num_samples, 3, figsize=(15, 5 * num_samples))

        for i in range(min(num_samples, images.shape[0])):
            axes[i, 0].imshow(images[i])
            axes[i, 0].set_title('Original Image')
            axes[i, 0].axis('off')

            true_mask = np.argmax(masks[i].numpy(), axis=-1)
            axes[i, 1].imshow(true_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 1].set_title('True Mask')
            axes[i, 1].axis('off')

            pred_mask = np.argmax(predictions[i], axis=-1)
            axes[i, 2].imshow(pred_mask, cmap='tab10', vmin=0, vmax=NUM_CLASSES - 1)
            axes[i, 2].set_title('Predicted Mask')
            axes[i, 2].axis('off')

        plt.tight_layout()
        plt.show()
        break

# --- Ejecución principal ---
if __name__ == "__main__":
    if not os.path.exists(TRAIN_IMAGES_PATH):
        print(f"Error: La ruta de imágenes de entrenamiento NO existe: {TRAIN_IMAGES_PATH}")
        exit()
    if not os.path.exists(TRAIN_MASKS_PATH):
        print(f"Error: La ruta de máscaras de entrenamiento NO existe: {TRAIN_MASKS_PATH}")
        exit()
    if not os.path.exists(VAL_IMAGES_PATH):
        print(f"Error: La ruta de imágenes de validación NO existe: {VAL_IMAGES_PATH}")
        exit()
    if not os.path.exists(VAL_MASKS_PATH):
        print(f"Error: La ruta de máscaras de validación NO existe: {VAL_MASKS_PATH}")
        exit()

    print("Creando datasets...")
    train_ds, val_ds = create_datasets()

    print("Entrenando modelo...")
    model, history = train_model(train_ds, val_ds)

    print("Visualizando predicciones...")
    visualize_predictions(model, val_ds)

    print("¡Entrenamiento completado! El mejor modelo se guardó como 'best_weed_model.h5'")

    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['dice_coefficient'], label='Dice Coeff (Train)')
    plt.plot(history.history['val_dice_coefficient'], label='Dice Coeff (Validation)')
    plt.title('Dice Coefficient over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Dice Coefficient')
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Loss (Train)')
    plt.plot(history.history['val_loss'], label='Loss (Validation)')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.show()

    print("\nEvaluando el modelo final en el conjunto de validación:")
    final_metrics = model.evaluate(val_ds)
    print(f"Validation Loss: {final_metrics[0]:.4f}")
    print(f"Validation Dice Coefficient: {final_metrics[1]:.4f}")
    print(f"Validation IoU: {final_metrics[2]:.4f}")
    print(f"Validation Accuracy: {final_metrics[3]:.4f}")

    # Calculate IoU per class
    iou_per_class_values = []
    for images, masks in val_ds:
        predictions = model.predict(images)
        iou_per_class_values.append(iou_per_class(masks, predictions))

    iou_per_class_values = np.mean(iou_per_class_values, axis=0)
    class_names = ['Background', 'Cow-tongue', 'Dandelion', 'Kikuyo', 'Other', 'Potato']
    for i, iou in enumerate(iou_per_class_values):
        print(f"IoU for {class_names[i]}: {iou:.4f}")
# Out:
# Creando datasets...
# Found 1680 images and 1680 masks
# Found 210 images and 210 masks
# Training batches (approx): 105
# Validation batches (approx): 14
# Entrenando modelo...
# Model: "WeedDetectionModel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ EfficientNetV2B0_B… │ [(None, 64, 64,   │  5,919,312 │ input_layer[0][0] │
# │ (Functional)        │ 16), (None, 32,   │            │                   │
# │                     │ 32, 64), (None,   │            │                   │
# │                     │ 16, 16, 128),     │            │                   │
# │                     │ (None, 16, 16,    │            │                   │
# │                     │ 192), (None, 4,   │            │                   │
# │                     │ 4, 1280)]         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module         │ (None, 4, 4, 64)  │  1,656,064 │ EfficientNetV2B0… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ deformable_attenti… │ (None, 4, 4, 64)  │     41,472 │ aspp_module[0][0] │
# │ (DeformableAttenti… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 8, 8, 64)  │     16,384 │ deformable_atten… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 16, 16,    │     16,384 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 16, 16,    │      4,096 │ EfficientNetV2B0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 96)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │     55,296 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │     36,864 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 32, 32, 6) │      1,536 │ batch_normalizat… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32, 6) │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 64, 64, 6) │        144 │ batch_normalizat… │
# │ (Conv2DTranspose)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64, 6) │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 128, 128,  │        144 │ batch_normalizat… │
# │ (Conv2DTranspose)   │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         24 │ conv2d_transpose… │
# │ (BatchNormalizatio… │ 6)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 128, 128,  │         42 │ batch_normalizat… │
# │ (Conv2D)            │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,748,962 (29.56 MB)
#  Trainable params: 7,686,846 (29.32 MB)
#  Non-trainable params: 62,116 (242.64 KB)
# Starting training for 50 epochs...
# Epoch 1/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2297 - dice_coefficient: 0.0890 - iou_metric: 0.1303 - loss: 2.9075
# Epoch 1: val_dice_coefficient improved from -inf to 0.09068, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 127s 204ms/step - accuracy: 0.2304 - dice_coefficient: 0.0890 - iou_metric: 0.1307 - loss: 2.9060 - val_accuracy: 0.3921 - val_dice_coefficient: 0.0907 - val_iou_metric: 0.2443 - val_loss: 2.6701 - learning_rate: 1.0000e-04
# Epoch 2/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.4137 - dice_coefficient: 0.0896 - iou_metric: 0.2646 - loss: 2.7025
# Epoch 2: val_dice_coefficient improved from 0.09068 to 0.09245, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 19s 73ms/step - accuracy: 0.4141 - dice_coefficient: 0.0896 - iou_metric: 0.2649 - loss: 2.7023 - val_accuracy: 0.4808 - val_dice_coefficient: 0.0925 - val_iou_metric: 0.3148 - val_loss: 2.6953 - learning_rate: 1.0000e-04
# Epoch 3/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5624 - dice_coefficient: 0.0919 - iou_metric: 0.4006 - loss: 2.6417
# Epoch 3: val_dice_coefficient did not improve from 0.09245
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.5627 - dice_coefficient: 0.0919 - iou_metric: 0.4009 - loss: 2.6416 - val_accuracy: 0.1221 - val_dice_coefficient: 0.0754 - val_iou_metric: 0.0649 - val_loss: 3.4430 - learning_rate: 1.0000e-04
# Epoch 4/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6577 - dice_coefficient: 0.1006 - iou_metric: 0.5141 - loss: 2.5234
# Epoch 4: val_dice_coefficient did not improve from 0.09245
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.6580 - dice_coefficient: 0.1007 - iou_metric: 0.5144 - loss: 2.5228 - val_accuracy: 0.0817 - val_dice_coefficient: 0.0632 - val_iou_metric: 0.0419 - val_loss: 4.2711 - learning_rate: 1.0000e-04
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7576 - dice_coefficient: 0.1247 - iou_metric: 0.6383 - loss: 2.2954
# Epoch 5: val_dice_coefficient improved from 0.09245 to 0.14756, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 81ms/step - accuracy: 0.7577 - dice_coefficient: 0.1248 - iou_metric: 0.6385 - loss: 2.2950 - val_accuracy: 0.5444 - val_dice_coefficient: 0.1476 - val_iou_metric: 0.3862 - val_loss: 8.0732 - learning_rate: 1.0000e-04
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8027 - dice_coefficient: 0.1429 - iou_metric: 0.6969 - loss: 2.1228
# Epoch 6: val_dice_coefficient did not improve from 0.14756
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.8028 - dice_coefficient: 0.1429 - iou_metric: 0.6970 - loss: 2.1224 - val_accuracy: 0.4224 - val_dice_coefficient: 0.1364 - val_iou_metric: 0.2722 - val_loss: 16.2391 - learning_rate: 1.0000e-04
# Epoch 7/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8310 - dice_coefficient: 0.1609 - iou_metric: 0.7319 - loss: 1.9743
# Epoch 7: val_dice_coefficient did not improve from 0.14756
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.8311 - dice_coefficient: 0.1610 - iou_metric: 0.7320 - loss: 1.9741 - val_accuracy: 0.2588 - val_dice_coefficient: 0.1074 - val_iou_metric: 0.1471 - val_loss: 281.2748 - learning_rate: 1.0000e-04
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8474 - dice_coefficient: 0.1750 - iou_metric: 0.7533 - loss: 1.8638
# Epoch 8: val_dice_coefficient did not improve from 0.14756
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - accuracy: 0.8474 - dice_coefficient: 0.1750 - iou_metric: 0.7534 - loss: 1.8637 - val_accuracy: 0.2132 - val_dice_coefficient: 0.0995 - val_iou_metric: 0.1198 - val_loss: 442.4033 - learning_rate: 1.0000e-04
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8629 - dice_coefficient: 0.1844 - iou_metric: 0.7742 - loss: 1.7783
# Epoch 9: val_dice_coefficient did not improve from 0.14756
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.8629 - dice_coefficient: 0.1844 - iou_metric: 0.7742 - loss: 1.7780 - val_accuracy: 0.3735 - val_dice_coefficient: 0.1080 - val_iou_metric: 0.2294 - val_loss: 2.7306 - learning_rate: 1.0000e-04
# Epoch 10/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8794 - dice_coefficient: 0.2008 - iou_metric: 0.7983 - loss: 1.6765
# Epoch 10: val_dice_coefficient did not improve from 0.14756
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 72ms/step - accuracy: 0.8794 - dice_coefficient: 0.2008 - iou_metric: 0.7983 - loss: 1.6764 - val_accuracy: 0.1181 - val_dice_coefficient: 0.0643 - val_iou_metric: 0.0633 - val_loss: 19.9037 - learning_rate: 1.0000e-04
# Epoch 11/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8883 - dice_coefficient: 0.2153 - iou_metric: 0.8124 - loss: 1.5956
# Epoch 11: val_dice_coefficient improved from 0.14756 to 0.22146, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.8883 - dice_coefficient: 0.2153 - iou_metric: 0.8124 - loss: 1.5956 - val_accuracy: 0.8917 - val_dice_coefficient: 0.2215 - val_iou_metric: 0.8117 - val_loss: 1.5315 - learning_rate: 1.0000e-04
# Epoch 12/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8919 - dice_coefficient: 0.2260 - iou_metric: 0.8188 - loss: 1.5271
# Epoch 12: val_dice_coefficient did not improve from 0.22146
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.8919 - dice_coefficient: 0.2259 - iou_metric: 0.8188 - loss: 1.5271 - val_accuracy: 0.1270 - val_dice_coefficient: 0.0661 - val_iou_metric: 0.0748 - val_loss: 49.8519 - learning_rate: 1.0000e-04
# Epoch 13/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8924 - dice_coefficient: 0.2311 - iou_metric: 0.8192 - loss: 1.4888
# Epoch 13: val_dice_coefficient did not improve from 0.22146
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - accuracy: 0.8924 - dice_coefficient: 0.2311 - iou_metric: 0.8192 - loss: 1.4888 - val_accuracy: 0.8722 - val_dice_coefficient: 0.2118 - val_iou_metric: 0.7927 - val_loss: 1.6815 - learning_rate: 1.0000e-04
# Epoch 14/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8921 - dice_coefficient: 0.2360 - iou_metric: 0.8190 - loss: 1.4571
# Epoch 14: val_dice_coefficient did not improve from 0.22146
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.8922 - dice_coefficient: 0.2360 - iou_metric: 0.8191 - loss: 1.4571 - val_accuracy: 0.1212 - val_dice_coefficient: 0.0583 - val_iou_metric: 0.0664 - val_loss: 19.9309 - learning_rate: 1.0000e-04
# Epoch 15/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8978 - dice_coefficient: 0.2502 - iou_metric: 0.8275 - loss: 1.3828
# Epoch 15: val_dice_coefficient did not improve from 0.22146
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.8978 - dice_coefficient: 0.2502 - iou_metric: 0.8275 - loss: 1.3830 - val_accuracy: 0.0972 - val_dice_coefficient: 0.0404 - val_iou_metric: 0.0562 - val_loss: 17.9518 - learning_rate: 1.0000e-04
# Epoch 16/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9004 - dice_coefficient: 0.2534 - iou_metric: 0.8318 - loss: 1.3502
# Epoch 16: val_dice_coefficient did not improve from 0.22146
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - accuracy: 0.9004 - dice_coefficient: 0.2533 - iou_metric: 0.8317 - loss: 1.3503 - val_accuracy: 0.1379 - val_dice_coefficient: 0.0679 - val_iou_metric: 0.0780 - val_loss: 101.7076 - learning_rate: 1.0000e-04
# Epoch 17/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9010 - dice_coefficient: 0.2554 - iou_metric: 0.8334 - loss: 1.3375
# Epoch 17: val_dice_coefficient did not improve from 0.22146
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.9010 - dice_coefficient: 0.2555 - iou_metric: 0.8334 - loss: 1.3374 - val_accuracy: 0.1921 - val_dice_coefficient: 0.0722 - val_iou_metric: 0.1167 - val_loss: 5.2378 - learning_rate: 1.0000e-04
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9045 - dice_coefficient: 0.2683 - iou_metric: 0.8366 - loss: 1.2815
# Epoch 18: val_dice_coefficient did not improve from 0.22146
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.9044 - dice_coefficient: 0.2683 - iou_metric: 0.8366 - loss: 1.2815 - val_accuracy: 0.1639 - val_dice_coefficient: 0.0660 - val_iou_metric: 0.0952 - val_loss: 8.7703 - learning_rate: 1.0000e-04
# Epoch 19/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9014 - dice_coefficient: 0.2731 - iou_metric: 0.8335 - loss: 1.2620
# Epoch 19: val_dice_coefficient did not improve from 0.22146
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.9014 - dice_coefficient: 0.2730 - iou_metric: 0.8335 - loss: 1.2622 - val_accuracy: 0.2045 - val_dice_coefficient: 0.0799 - val_iou_metric: 0.1157 - val_loss: 4.7839 - learning_rate: 1.0000e-04
# Epoch 20/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9004 - dice_coefficient: 0.2776 - iou_metric: 0.8316 - loss: 1.2441
# Epoch 20: val_dice_coefficient did not improve from 0.22146
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.9004 - dice_coefficient: 0.2775 - iou_metric: 0.8317 - loss: 1.2441 - val_accuracy: 0.1407 - val_dice_coefficient: 0.0701 - val_iou_metric: 0.0759 - val_loss: 13.2712 - learning_rate: 1.0000e-04
# Epoch 21/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9095 - dice_coefficient: 0.2853 - iou_metric: 0.8457 - loss: 1.1962
# Epoch 21: val_dice_coefficient improved from 0.22146 to 0.26710, saving model to best_weed_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.9095 - dice_coefficient: 0.2853 - iou_metric: 0.8457 - loss: 1.1963 - val_accuracy: 0.8999 - val_dice_coefficient: 0.2671 - val_iou_metric: 0.8357 - val_loss: 1.2120 - learning_rate: 1.0000e-04
# Epoch 22/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9062 - dice_coefficient: 0.2888 - iou_metric: 0.8415 - loss: 1.1889
# Epoch 22: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.9062 - dice_coefficient: 0.2888 - iou_metric: 0.8415 - loss: 1.1889 - val_accuracy: 0.0856 - val_dice_coefficient: 0.0387 - val_iou_metric: 0.0551 - val_loss: 31.9229 - learning_rate: 1.0000e-04
# Epoch 23/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9075 - dice_coefficient: 0.2978 - iou_metric: 0.8429 - loss: 1.1556
# Epoch 23: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - accuracy: 0.9075 - dice_coefficient: 0.2978 - iou_metric: 0.8429 - loss: 1.1557 - val_accuracy: 0.1645 - val_dice_coefficient: 0.0739 - val_iou_metric: 0.0893 - val_loss: 6.0287 - learning_rate: 1.0000e-04
# Epoch 24/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9050 - dice_coefficient: 0.3039 - iou_metric: 0.8401 - loss: 1.1395
# Epoch 24: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.9050 - dice_coefficient: 0.3038 - iou_metric: 0.8402 - loss: 1.1398 - val_accuracy: 0.2501 - val_dice_coefficient: 0.0946 - val_iou_metric: 0.1433 - val_loss: 4.9461 - learning_rate: 1.0000e-04
# Epoch 25/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9100 - dice_coefficient: 0.3037 - iou_metric: 0.8477 - loss: 1.1235
# Epoch 25: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.9099 - dice_coefficient: 0.3037 - iou_metric: 0.8476 - loss: 1.1236 - val_accuracy: 0.3044 - val_dice_coefficient: 0.1034 - val_iou_metric: 0.1815 - val_loss: 7.0457 - learning_rate: 1.0000e-04
# Epoch 26/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9125 - dice_coefficient: 0.3109 - iou_metric: 0.8514 - loss: 1.1007
# Epoch 26: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.9124 - dice_coefficient: 0.3109 - iou_metric: 0.8514 - loss: 1.1007 - val_accuracy: 0.2316 - val_dice_coefficient: 0.1011 - val_iou_metric: 0.1316 - val_loss: 9.1360 - learning_rate: 1.0000e-04
# Epoch 27/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9105 - dice_coefficient: 0.3121 - iou_metric: 0.8483 - loss: 1.0931
# Epoch 27: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.9105 - dice_coefficient: 0.3121 - iou_metric: 0.8483 - loss: 1.0931 - val_accuracy: 0.2911 - val_dice_coefficient: 0.0973 - val_iou_metric: 0.1693 - val_loss: 6.6092 - learning_rate: 1.0000e-04
# Epoch 28/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9103 - dice_coefficient: 0.3182 - iou_metric: 0.8486 - loss: 1.0745
# Epoch 28: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 11s 66ms/step - accuracy: 0.9103 - dice_coefficient: 0.3183 - iou_metric: 0.8486 - loss: 1.0745 - val_accuracy: 0.1380 - val_dice_coefficient: 0.0713 - val_iou_metric: 0.0753 - val_loss: 33.4465 - learning_rate: 1.0000e-04
# Epoch 29/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9102 - dice_coefficient: 0.3239 - iou_metric: 0.8472 - loss: 1.0600
# Epoch 29: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - accuracy: 0.9102 - dice_coefficient: 0.3239 - iou_metric: 0.8472 - loss: 1.0600 - val_accuracy: 0.2108 - val_dice_coefficient: 0.0851 - val_iou_metric: 0.1171 - val_loss: 7.5024 - learning_rate: 1.0000e-04
# Epoch 30/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9105 - dice_coefficient: 0.3285 - iou_metric: 0.8493 - loss: 1.0468
# Epoch 30: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.9105 - dice_coefficient: 0.3284 - iou_metric: 0.8494 - loss: 1.0469 - val_accuracy: 0.1043 - val_dice_coefficient: 0.0382 - val_iou_metric: 0.0603 - val_loss: 53.1719 - learning_rate: 1.0000e-04
# Epoch 31/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9155 - dice_coefficient: 0.3367 - iou_metric: 0.8561 - loss: 1.0160
# Epoch 31: val_dice_coefficient did not improve from 0.26710
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - accuracy: 0.9155 - dice_coefficient: 0.3367 - iou_metric: 0.8560 - loss: 1.0161 - val_accuracy: 0.1194 - val_dice_coefficient: 0.0687 - val_iou_metric: 0.0799 - val_loss: 13.7052 - learning_rate: 1.0000e-04
# Epoch 32/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9150 - dice_coefficient: 0.3392 - iou_metric: 0.8550 - loss: 1.0153
# Epoch 32: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.9149 - dice_coefficient: 0.3392 - iou_metric: 0.8550 - loss: 1.0153 - val_accuracy: 0.8053 - val_dice_coefficient: 0.1553 - val_iou_metric: 0.6916 - val_loss: 1.7838 - learning_rate: 5.0000e-05
# Epoch 33/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9119 - dice_coefficient: 0.3438 - iou_metric: 0.8507 - loss: 1.0060
# Epoch 33: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.9119 - dice_coefficient: 0.3437 - iou_metric: 0.8507 - loss: 1.0060 - val_accuracy: 0.1061 - val_dice_coefficient: 0.0697 - val_iou_metric: 0.0676 - val_loss: 12.4017 - learning_rate: 5.0000e-05
# Epoch 34/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9131 - dice_coefficient: 0.3453 - iou_metric: 0.8531 - loss: 1.0001
# Epoch 34: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.9131 - dice_coefficient: 0.3453 - iou_metric: 0.8531 - loss: 1.0001 - val_accuracy: 0.0973 - val_dice_coefficient: 0.0368 - val_iou_metric: 0.0649 - val_loss: 33.2539 - learning_rate: 5.0000e-05
# Epoch 35/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9110 - dice_coefficient: 0.3435 - iou_metric: 0.8503 - loss: 1.0080
# Epoch 35: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.9111 - dice_coefficient: 0.3435 - iou_metric: 0.8503 - loss: 1.0079 - val_accuracy: 0.8174 - val_dice_coefficient: 0.2569 - val_iou_metric: 0.6941 - val_loss: 1.4870 - learning_rate: 5.0000e-05
# Epoch 36/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9131 - dice_coefficient: 0.3472 - iou_metric: 0.8525 - loss: 0.9928
# Epoch 36: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - accuracy: 0.9131 - dice_coefficient: 0.3471 - iou_metric: 0.8526 - loss: 0.9928 - val_accuracy: 0.6101 - val_dice_coefficient: 0.1387 - val_iou_metric: 0.4489 - val_loss: 2.4439 - learning_rate: 5.0000e-05
# Epoch 37/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9149 - dice_coefficient: 0.3438 - iou_metric: 0.8552 - loss: 0.9963
# Epoch 37: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.9149 - dice_coefficient: 0.3438 - iou_metric: 0.8552 - loss: 0.9962 - val_accuracy: 0.0989 - val_dice_coefficient: 0.0635 - val_iou_metric: 0.0628 - val_loss: 36.7707 - learning_rate: 5.0000e-05
# Epoch 38/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9161 - dice_coefficient: 0.3506 - iou_metric: 0.8573 - loss: 0.9789
# Epoch 38: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 70ms/step - accuracy: 0.9161 - dice_coefficient: 0.3506 - iou_metric: 0.8573 - loss: 0.9790 - val_accuracy: 0.0869 - val_dice_coefficient: 0.0410 - val_iou_metric: 0.0483 - val_loss: 116.1425 - learning_rate: 5.0000e-05
# Epoch 39/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9138 - dice_coefficient: 0.3568 - iou_metric: 0.8542 - loss: 0.9716
# Epoch 39: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - accuracy: 0.9139 - dice_coefficient: 0.3567 - iou_metric: 0.8542 - loss: 0.9716 - val_accuracy: 0.1055 - val_dice_coefficient: 0.0698 - val_iou_metric: 0.0622 - val_loss: 17.7203 - learning_rate: 5.0000e-05
# Epoch 40/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9171 - dice_coefficient: 0.3582 - iou_metric: 0.8591 - loss: 0.9588
# Epoch 40: val_dice_coefficient did not improve from 0.26710
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.9171 - dice_coefficient: 0.3582 - iou_metric: 0.8591 - loss: 0.9589 - val_accuracy: 0.1016 - val_dice_coefficient: 0.0335 - val_iou_metric: 0.0607 - val_loss: 13.8931 - learning_rate: 5.0000e-05
# Epoch 41/50
# 104/105 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9117 - dice_coefficient: 0.3536 - iou_metric: 0.8511 - loss: 0.9831
# Epoch 41: val_dice_coefficient did not improve from 0.26710
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.9118 - dice_coefficient: 0.3537 - iou_metric: 0.8512 - loss: 0.9829 - val_accuracy: 0.7777 - val_dice_coefficient: 0.2128 - val_iou_metric: 0.6511 - val_loss: 1.8449 - learning_rate: 5.0000e-05
# Visualizando predicciones...
# Visualizing 4 samples from the validation set...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# ¡Entrenamiento completado! El mejor modelo se guardó como 'best_weed_model.h5'
# Evaluando el modelo final en el conjunto de validación:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8984 - dice_coefficient: 0.2776 - iou_metric: 0.8279 - loss: 1.2070
# Validation Loss: 1.2068
# Validation Dice Coefficient: 0.2773
# Validation IoU: 0.8335
# Validation Accuracy: 0.8999
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# IoU for Background: 0.9086
# IoU for Cow-tongue: 0.3173
# IoU for Dandelion: 0.2676
# IoU for Kikuyo: 0.3884
# IoU for Other: 0.6607
# IoU for Potato: 0.4615
