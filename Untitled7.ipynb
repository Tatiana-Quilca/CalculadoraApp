# %% [markdown]
# <a href="https://colab.research.google.com/github/Tatiana-Quilca/CalculadoraApp/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import cv2
import os
from glob import glob
import zipfile

# Descomprimir el dataset
with zipfile.ZipFile("Balanced.zip", 'r') as zip_ref:
    zip_ref.extractall("Balanced")

# --- FORCE ALL COMPUTATIONS TO FLOAT32 ---
tf.keras.mixed_precision.set_global_policy('float32')

# -------------------- CONFIGURACIÓN --------------------
IMG_HEIGHT = 128
IMG_WIDTH = 128
NUM_CLASSES = 6
BATCH_SIZE = 16
EPOCHS = 50
LEARNING_RATE = 1e-3
DATASET_ROOT_PATH = "Balanced"

# -------------------- CBAM MODULE --------------------
class CBAMModule(layers.Layer):
    def __init__(self, channels, reduction_ratio=16, **kwargs):
        super(CBAMModule, self).__init__(**kwargs)
        self.channels = channels
        self.reduction_ratio = reduction_ratio
        self.channel_avg_pool = layers.GlobalAveragePooling2D()
        self.channel_max_pool = layers.GlobalMaxPooling2D()
        self.channel_fc1 = layers.Dense(channels // reduction_ratio, activation='relu')
        self.channel_fc2 = layers.Dense(channels, activation='sigmoid')
        self.spatial_conv = layers.Conv2D(1, 7, padding='same', activation='sigmoid')

    def call(self, inputs):
        avg_pool = self.channel_avg_pool(inputs)
        max_pool = self.channel_max_pool(inputs)
        avg_out = self.channel_fc2(self.channel_fc1(avg_pool))
        max_out = self.channel_fc2(self.channel_fc1(max_pool))
        channel_attention = layers.Add()([avg_out, max_out])
        channel_attention = layers.Reshape((1, 1, self.channels))(channel_attention)
        channel_refined = layers.Multiply()([inputs, channel_attention])

        avg_spatial = tf.reduce_mean(channel_refined, axis=-1, keepdims=True)
        max_spatial = tf.reduce_max(channel_refined, axis=-1, keepdims=True)
        spatial_concat = layers.Concatenate(axis=-1)([avg_spatial, max_spatial])
        spatial_attention = self.spatial_conv(spatial_concat)
        spatial_refined = layers.Multiply()([channel_refined, spatial_attention])
        return spatial_refined

# -------------------- ASPP MODULE --------------------
class ASPPModule(layers.Layer):
    def __init__(self, filters=256, **kwargs):
        super(ASPPModule, self).__init__(**kwargs)
        self.filters = filters
        self.conv_1x1 = layers.Conv2D(filters, 1, padding='same', kernel_regularizer=regularizers.l2(1e-4))
        self.bn_1x1 = layers.BatchNormalization()
        self.conv_3x3_2 = layers.Conv2D(filters, 3, padding='same', dilation_rate=2, kernel_regularizer=regularizers.l2(1e-4))
        self.bn_3x3_2 = layers.BatchNormalization()
        self.conv_3x3_4 = layers.Conv2D(filters, 3, padding='same', dilation_rate=4, kernel_regularizer=regularizers.l2(1e-4))
        self.bn_3x3_4 = layers.BatchNormalization()
        self.conv_3x3_8 = layers.Conv2D(filters, 3, padding='same', dilation_rate=8, kernel_regularizer=regularizers.l2(1e-4))
        self.bn_3x3_8 = layers.BatchNormalization()
        self.global_avg_pool = layers.GlobalAveragePooling2D(keepdims=True)
        self.conv_1x1_gap = layers.Conv2D(filters, 1, padding='same', kernel_regularizer=regularizers.l2(1e-4))
        self.bn_gap = layers.BatchNormalization()
        self.conv_final = layers.Conv2D(filters, 1, padding='same', kernel_regularizer=regularizers.l2(1e-4))
        self.bn_final = layers.BatchNormalization()
        self.dropout = layers.Dropout(0.4)

    def call(self, inputs, training=None):
        input_shape = tf.shape(inputs)
        conv_1x1 = tf.nn.relu(self.bn_1x1(self.conv_1x1(inputs), training=training))
        conv_3x3_2 = tf.nn.relu(self.bn_3x3_2(self.conv_3x3_2(inputs), training=training))
        conv_3x3_4 = tf.nn.relu(self.bn_3x3_4(self.conv_3x3_4(inputs), training=training))
        conv_3x3_8 = tf.nn.relu(self.bn_3x3_8(self.conv_3x3_8(inputs), training=training))

        gap = self.global_avg_pool(inputs)
        gap = tf.image.resize(gap, [input_shape[1], input_shape[2]])
        gap = tf.nn.relu(self.bn_gap(self.conv_1x1_gap(gap), training=training))

        concat = layers.Concatenate()([conv_1x1, conv_3x3_2, conv_3x3_4, conv_3x3_8, gap])
        output = tf.nn.relu(self.bn_final(self.conv_final(concat), training=training))
        return self.dropout(output, training=training)

# -------------------- CONVNEXT BACKBONE --------------------
def create_convnext_backbone(input_shape):
    base_model = tf.keras.applications.ConvNeXtBase(
        input_shape=input_shape, weights='imagenet', include_top=False
    )
    layer_names = [
        'convnext_base_stage_0_block_0_layer_scale',
        'convnext_base_stage_1_block_0_layer_scale',
        'convnext_base_stage_2_block_0_layer_scale',
        'convnext_base_stage_3_block_2_layer_scale'
    ]
    outputs = [base_model.get_layer(name).output for name in layer_names]
    casted_outputs = [layers.Lambda(lambda x: tf.cast(x, tf.keras.backend.floatx()))(o) for o in outputs]
    return tf.keras.Model(inputs=base_model.input, outputs=casted_outputs)

# -------------------- MODELO PRINCIPAL --------------------
def create_model(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape, dtype=tf.keras.backend.floatx())

    backbone = create_convnext_backbone(input_shape)
    features = backbone(inputs)

    early, mid, deep = features[0], features[2], features[-1]

    aspp = ASPPModule(256)(deep)
    cbam = CBAMModule(256)(aspp)
    decoder = layers.UpSampling2D((4, 4))(cbam)

    early = layers.Conv2D(64, 1, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(early)
    early = layers.BatchNormalization()(early)
    early = layers.UpSampling2D((2, 2))(early)

    mid = layers.Conv2D(96, 1, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(mid)
    mid = layers.BatchNormalization()(mid)
    mid = layers.UpSampling2D((2, 2))(mid)

    x = layers.Concatenate()([decoder, mid])
    x = layers.Conv2D(256, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(256, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.UpSampling2D((4, 4))(x)

    x = layers.Concatenate()([x, early])
    x = layers.Conv2D(128, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, 3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.BatchNormalization()(x)
    x = layers.UpSampling2D((2, 2))(x)

    outputs = layers.Conv2D(num_classes, 1, activation='softmax', dtype=tf.keras.backend.floatx())(x)
    return keras.Model(inputs, outputs)

# -------------------- MÉTRICAS PERSONALIZADAS --------------------
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1.0 - tf.keras.backend.epsilon())

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3])
    dice = (2. * intersection + smooth) / (union + smooth)
    return tf.reduce_mean(dice)

def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1.0 - tf.keras.backend.epsilon())

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred, axis=[1, 2, 3]) - intersection
    return tf.reduce_mean((intersection + smooth) / (union + smooth))

class DiceLoss(tf.keras.losses.Loss):
    def __init__(self, name="dice_loss", smooth=1e-6):
        super(DiceLoss, self).__init__(name=name)
        self.smooth = smooth

    def call(self, y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        y_pred = tf.clip_by_value(y_pred, tf.keras.backend.epsilon(), 1.0 - tf.keras.backend.epsilon())

        y_true_f = tf.reshape(y_true, [-1, NUM_CLASSES])
        y_pred_f = tf.reshape(y_pred, [-1, NUM_CLASSES])

        intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=0)
        union = tf.reduce_sum(y_true_f + y_pred_f, axis=0)

        dice = (2. * intersection + self.smooth) / (union + self.smooth)
        return 1.0 - tf.reduce_mean(dice)

class FocalLoss(tf.keras.losses.Loss):
    def __init__(self, gamma=2.0, alpha=0.25, name="focal_loss"):
        super(FocalLoss, self).__init__(name=name)
        self.gamma = gamma
        self.alpha = alpha

    def call(self, y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)

        cross_entropy = -y_true * tf.math.log(y_pred)

        pt = y_pred * y_true + (1 - y_pred) * (1 - y_true)
        loss = self.alpha * tf.pow(1. - pt, self.gamma) * cross_entropy
        return tf.reduce_mean(tf.reduce_sum(loss, axis=-1))

# -------------------- PREPARAR DATOS --------------------
def load_data_and_create_datasets():
    image_paths = []
    mask_paths = []

    for subset in ['train', 'test', 'val']:
        image_paths.extend(sorted(glob(f"{DATASET_ROOT_PATH}/Balanced/{subset}/images/*")))
        mask_paths.extend(sorted(glob(f"{DATASET_ROOT_PATH}/Balanced/{subset}/masks/*")))

    if not image_paths or not mask_paths:
        raise ValueError(f"No images or masks found. Check the dataset path: {DATASET_ROOT_PATH}. "
                         f"Found images: {len(image_paths)}, masks: {len(mask_paths)}")

    images = [cv2.resize(cv2.imread(p), (IMG_WIDTH, IMG_HEIGHT)).astype(np.float32) for p in image_paths]
    masks = [cv2.resize(cv2.imread(p, cv2.IMREAD_GRAYSCALE), (IMG_WIDTH, IMG_HEIGHT), interpolation=cv2.INTER_NEAREST).astype(np.int32) for p in mask_paths]

    images = np.array(images) / 255.0
    masks = np.array(masks)
    masks_one_hot = keras.utils.to_categorical(masks, num_classes=NUM_CLASSES)

    flat_masks_int = np.argmax(masks_one_hot, axis=-1).flatten()
    class_counts = np.bincount(flat_masks_int, minlength=NUM_CLASSES)
    class_counts = np.where(class_counts == 0, 1, class_counts)
    total_samples = len(flat_masks_int)
    class_weights = total_samples / (NUM_CLASSES * class_counts)
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
    print(f"Calculated Class Weights: {class_weights_dict}")

    X_train_raw, X_val_raw, y_train_raw, y_val_raw = train_test_split(images, masks_one_hot, test_size=0.2, random_state=42)

    def augment_fn(image, mask):
        if tf.random.uniform(()) > 0.5:
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)

        if tf.random.uniform(()) > 0.5:
            image = tf.image.flip_up_down(image)
            mask = tf.image.flip_up_down(mask)

        k = tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32)
        image = tf.image.rot90(image, k)
        mask = tf.image.rot90(mask, k)

        image = tf.image.random_brightness(image, max_delta=0.1)
        image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
        return image, mask

    def preprocess_fn(image, mask):
        image = tf.image.convert_image_dtype(image, tf.float32)
        mask = tf.image.convert_image_dtype(mask, tf.float32)
        return image, mask

    train_dataset = tf.data.Dataset.from_tensor_slices((X_train_raw, y_train_raw))
    train_dataset = train_dataset.shuffle(buffer_size=len(X_train_raw)) \
                                 .map(augment_fn, num_parallel_calls=tf.data.AUTOTUNE) \
                                 .map(preprocess_fn, num_parallel_calls=tf.data.AUTOTUNE) \
                                 .batch(BATCH_SIZE) \
                                 .prefetch(tf.data.AUTOTUNE)

    val_dataset = tf.data.Dataset.from_tensor_slices((X_val_raw, y_val_raw))
    val_dataset = val_dataset.map(preprocess_fn, num_parallel_calls=tf.data.AUTOTUNE) \
                             .batch(BATCH_SIZE) \
                             .prefetch(tf.data.AUTOTUNE)

    return train_dataset, val_dataset, X_val_raw, y_val_raw, class_weights_dict

train_ds, val_ds, X_val_raw, y_val_raw, class_weights = load_data_and_create_datasets()

# -------------------- COMPILAR Y ENTRENAR --------------------
model = create_model()

print("\nModel Summary:")
model.summary()

custom_loss = DiceLoss(name="dice_loss")

model.compile(optimizer=keras.optimizers.Adam(LEARNING_RATE),
              loss=custom_loss,
              metrics=[iou_metric, dice_coefficient, 'accuracy'])

callbacks = [
    tf.keras.callbacks.ModelCheckpoint("best_model.keras", save_best_only=True, monitor='val_loss', mode='min', verbose=1),
    tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True, monitor='val_loss', mode='min', verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=10, min_lr=1e-6, verbose=1, monitor='val_loss', mode='min')
]

history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=EPOCHS,
                    callbacks=callbacks,
                    class_weight=class_weights)

# -------------------- GUARDAR MODELO --------------------
model.save("final_model.keras")

# -------------------- MOSTRAR MÉTRICAS --------------------
print("\nEvaluación final (usando el mejor modelo guardado):")
try:
    best_model = keras.models.load_model("best_model.keras",
                                         custom_objects={
                                             'DiceLoss': DiceLoss,
                                             'iou_metric': iou_metric,
                                             'dice_coefficient': dice_coefficient,
                                             'FocalLoss': FocalLoss
                                         },
                                         safe_mode=False)
    results = best_model.evaluate(val_ds, verbose=2)
    print(f"Pérdida (Dice Loss): {results[0]:.4f}")
    print(f"IoU: {results[1]:.4f}")
    print(f"DICE: {results[2]:.4f}")
    print(f"Precisión: {results[3]:.4f}")
except Exception as e:
    print(f"Error loading best_model.keras: {e}")
    print("Cannot evaluate best model from file. Displaying metrics from training history instead.")
    best_epoch = np.argmin(history.history['val_loss'])
    print(f"\nBest epoch (based on validation loss): {best_epoch + 1}")
    print(f"Best Validation Loss: {history.history['val_loss'][best_epoch]:.4f}")
    print(f"Best Validation IoU: {history.history['val_iou_metric'][best_epoch]:.4f}")
    print(f"Best Validation DICE: {history.history['val_dice_coefficient'][best_epoch]:.4f}")
    print(f"Best Validation Accuracy: {history.history['val_accuracy'][best_epoch]:.4f}")

# -------------------- VISUALIZACIÓN DE MÉTRICAS DEL ENTRENAMIENTO --------------------
print("\nVisualizing Training History:")
plt.figure(figsize=(15, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['iou_metric'], label='Training IoU')
plt.plot(history.history['val_iou_metric'], label='Validation IoU')
plt.plot(history.history['dice_coefficient'], label='Training DICE')
plt.plot(history.history['val_dice_coefficient'], label='Validation DICE')
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Metrics over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.legend()
plt.grid(True)
plt.show()

# -------------------- VISUALIZACIÓN DE PREDICCIONES --------------------
print("\nVisualizing Predictions from Best Model:")
model_to_visualize = None
try:
    model_to_visualize = best_model
except NameError:
    model_to_visualize = model
    print("Using the last trained model for visualization as best_model could not be loaded.")

if model_to_visualize:
    def display_predictions(model_to_use, raw_images, raw_masks, num_samples=3):
        indices = np.random.choice(len(raw_images), num_samples, replace=False)

        for idx in indices:
            image = raw_images[idx]
            true_mask_one_hot = raw_masks[idx]

            input_image = tf.image.convert_image_dtype(image, tf.float32)
            input_image = tf.expand_dims(input_image, 0)

            pred_mask_probs = model_to_use.predict(input_image, verbose=0)[0]

            true_mask_single_channel = np.argmax(true_mask_one_hot, axis=-1)
            pred_mask_single_channel = np.argmax(pred_mask_probs, axis=-1)

            fig, axes = plt.subplots(1, 3, figsize=(15, 5))

            axes[0].imshow(image)
            axes[0].set_title('Original Image')
            axes[0].axis('off')

            axes[1].imshow(true_mask_single_channel, cmap='viridis', vmin=0, vmax=NUM_CLASSES-1)
            axes[1].set_title('Ground Truth Mask')
            axes[1].axis('off')

            axes[2].imshow(pred_mask_single_channel, cmap='viridis', vmin=0, vmax=NUM_CLASSES-1)
            axes[2].set_title('Predicted Mask')
            axes[2].axis('off')

            plt.tight_layout()
            plt.show()

    display_predictions(model_to_visualize, X_val_raw, y_val_raw, num_samples=5)
else:
    print("Could not visualize predictions as no model was successfully loaded or trained.")
# Out:
# Calculated Class Weights: {0: np.float64(0.20199047836666972), 1: np.float64(5.8397371792391155), 2: np.float64(11.995724180345873), 3: np.float64(6.9607691999558154), 4: np.float64(26.536845417692465), 5: np.float64(1.6304642973413686)}
#
# Model Summary:
# Model: "functional_20"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_18      │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_19       │ [(None, 32, 32,   │ 87,564,416 │ input_layer_18[0… │
# │ (Functional)        │ 128), (None, 16,  │            │                   │
# │                     │ 16, 256), (None,  │            │                   │
# │                     │ 8, 8, 512),       │            │                   │
# │                     │ (None, 4, 4,      │            │                   │
# │                     │ 1024)]            │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ aspp_module         │ (None, 4, 4, 256) │  7,937,536 │ functional_19[0]… │
# │ (ASPPModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 96)  │     49,248 │ functional_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cbam_module         │ (None, 4, 4, 256) │      8,563 │ aspp_module[0][0] │
# │ (CBAMModule)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 96)  │        384 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 16, 16,    │          0 │ cbam_module[0][0] │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 16, 16,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 352)              │            │ up_sampling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │    811,264 │ concatenate_4[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │      8,256 │ functional_19[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 320)              │            │ up_sampling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 64, 64,    │    368,768 │ concatenate_5[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 128,  │        774 │ up_sampling2d_4[… │
# │                     │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 97,490,201 (371.90 MB)
#  Trainable params: 97,485,273 (371.88 MB)
#  Non-trainable params: 4,928 (19.25 KB)
# Epoch 1/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.5995 - dice_coefficient: 0.5855 - iou_metric: 0.4318 - loss: 1.1257
# Epoch 1: val_loss improved from inf to 0.95438, saving model to best_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 246s 1s/step - accuracy: 0.6001 - dice_coefficient: 0.5862 - iou_metric: 0.4324 - loss: 1.1248 - val_accuracy: 0.7753 - val_dice_coefficient: 0.7709 - val_iou_metric: 0.6544 - val_loss: 0.9544 - learning_rate: 0.0010
# Epoch 2/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 612ms/step - accuracy: 0.6933 - dice_coefficient: 0.6904 - iou_metric: 0.5372 - loss: 0.9524
# Epoch 2: val_loss improved from 0.95438 to 0.94653, saving model to best_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.6933 - dice_coefficient: 0.6905 - iou_metric: 0.5372 - loss: 0.9520 - val_accuracy: 0.5110 - val_dice_coefficient: 0.5080 - val_iou_metric: 0.3470 - val_loss: 0.9465 - learning_rate: 0.0010
# Epoch 3/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - accuracy: 0.6989 - dice_coefficient: 0.6873 - iou_metric: 0.5344 - loss: 0.8603
# Epoch 3: val_loss did not improve from 0.94653
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 67s 633ms/step - accuracy: 0.6990 - dice_coefficient: 0.6874 - iou_metric: 0.5346 - loss: 0.8601 - val_accuracy: 0.0297 - val_dice_coefficient: 0.0319 - val_iou_metric: 0.0163 - val_loss: 1.0369 - learning_rate: 0.0010
# Epoch 4/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.7700 - dice_coefficient: 0.7533 - iou_metric: 0.6177 - loss: 0.8082
# Epoch 4: val_loss did not improve from 0.94653
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 82s 632ms/step - accuracy: 0.7704 - dice_coefficient: 0.7536 - iou_metric: 0.6182 - loss: 0.8077 - val_accuracy: 0.1214 - val_dice_coefficient: 0.1201 - val_iou_metric: 0.0818 - val_loss: 0.9983 - learning_rate: 0.0010
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.8358 - dice_coefficient: 0.8298 - iou_metric: 0.7199 - loss: 0.6879
# Epoch 5: val_loss improved from 0.94653 to 0.86665, saving model to best_model.keras
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.8358 - dice_coefficient: 0.8298 - iou_metric: 0.7199 - loss: 0.6881 - val_accuracy: 0.7919 - val_dice_coefficient: 0.7897 - val_iou_metric: 0.6895 - val_loss: 0.8666 - learning_rate: 0.0010
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.8256 - dice_coefficient: 0.8181 - iou_metric: 0.7053 - loss: 0.7021
# Epoch 6: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 97s 628ms/step - accuracy: 0.8254 - dice_coefficient: 0.8178 - iou_metric: 0.7050 - loss: 0.7024 - val_accuracy: 0.0226 - val_dice_coefficient: 0.0228 - val_iou_metric: 0.0117 - val_loss: 1.0090 - learning_rate: 0.0010
# Epoch 7/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.8177 - dice_coefficient: 0.8060 - iou_metric: 0.6864 - loss: 0.7163
# Epoch 7: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 65s 618ms/step - accuracy: 0.8178 - dice_coefficient: 0.8061 - iou_metric: 0.6865 - loss: 0.7163 - val_accuracy: 0.0717 - val_dice_coefficient: 0.0707 - val_iou_metric: 0.0409 - val_loss: 0.9902 - learning_rate: 0.0010
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - accuracy: 0.8570 - dice_coefficient: 0.8520 - iou_metric: 0.7547 - loss: 0.7076
# Epoch 8: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 84s 634ms/step - accuracy: 0.8571 - dice_coefficient: 0.8521 - iou_metric: 0.7548 - loss: 0.7076 - val_accuracy: 0.1214 - val_dice_coefficient: 0.1201 - val_iou_metric: 0.0818 - val_loss: 0.9846 - learning_rate: 0.0010
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - accuracy: 0.8619 - dice_coefficient: 0.8579 - iou_metric: 0.7653 - loss: 0.6736
# Epoch 9: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 81s 627ms/step - accuracy: 0.8620 - dice_coefficient: 0.8579 - iou_metric: 0.7654 - loss: 0.6736 - val_accuracy: 0.1214 - val_dice_coefficient: 0.1201 - val_iou_metric: 0.0818 - val_loss: 0.9811 - learning_rate: 0.0010
# Epoch 10/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.8713 - dice_coefficient: 0.8678 - iou_metric: 0.7808 - loss: 0.6489
# Epoch 10: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 65s 621ms/step - accuracy: 0.8713 - dice_coefficient: 0.8678 - iou_metric: 0.7808 - loss: 0.6490 - val_accuracy: 0.8105 - val_dice_coefficient: 0.8080 - val_iou_metric: 0.7196 - val_loss: 0.8671 - learning_rate: 0.0010
# Epoch 11/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.8630 - dice_coefficient: 0.8589 - iou_metric: 0.7664 - loss: 0.6526
# Epoch 11: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 66s 623ms/step - accuracy: 0.8631 - dice_coefficient: 0.8589 - iou_metric: 0.7665 - loss: 0.6525 - val_accuracy: 0.1214 - val_dice_coefficient: 0.1202 - val_iou_metric: 0.0818 - val_loss: 0.9798 - learning_rate: 0.0010
# Epoch 12/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - accuracy: 0.8697 - dice_coefficient: 0.8668 - iou_metric: 0.7790 - loss: 0.6161
# Epoch 12: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 83s 634ms/step - accuracy: 0.8694 - dice_coefficient: 0.8666 - iou_metric: 0.7787 - loss: 0.6164 - val_accuracy: 0.1214 - val_dice_coefficient: 0.1201 - val_iou_metric: 0.0818 - val_loss: 0.9847 - learning_rate: 0.0010
# Epoch 13/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.8075 - dice_coefficient: 0.7991 - iou_metric: 0.6820 - loss: 0.7452
# Epoch 13: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 65s 619ms/step - accuracy: 0.8077 - dice_coefficient: 0.7994 - iou_metric: 0.6824 - loss: 0.7448 - val_accuracy: 0.1214 - val_dice_coefficient: 0.1201 - val_iou_metric: 0.0818 - val_loss: 0.9954 - learning_rate: 0.0010
# Epoch 14/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.8165 - dice_coefficient: 0.8075 - iou_metric: 0.7014 - loss: 0.7308
# Epoch 14: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 83s 633ms/step - accuracy: 0.8165 - dice_coefficient: 0.8075 - iou_metric: 0.7014 - loss: 0.7307 - val_accuracy: 0.8105 - val_dice_coefficient: 0.8080 - val_iou_metric: 0.7196 - val_loss: 0.8806 - learning_rate: 0.0010
# Epoch 15/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.8682 - dice_coefficient: 0.8610 - iou_metric: 0.7708 - loss: 0.6530
# Epoch 15: val_loss did not improve from 0.86665
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 65s 618ms/step - accuracy: 0.8681 - dice_coefficient: 0.8610 - iou_metric: 0.7708 - loss: 0.6531 - val_accuracy: 0.2113 - val_dice_coefficient: 0.2080 - val_iou_metric: 0.1166 - val_loss: 0.9567 - learning_rate: 0.0010
# Epoch 16/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - accuracy: 0.8703 - dice_coefficient: 0.8642 - iou_metric: 0.7766 - loss: 0.6581
# Epoch 16: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 65s 619ms/step - accuracy: 0.8703 - dice_coefficient: 0.8642 - iou_metric: 0.7766 - loss: 0.6580 - val_accuracy: 0.1515 - val_dice_coefficient: 0.1481 - val_iou_metric: 0.0977 - val_loss: 0.9745 - learning_rate: 5.0000e-04
# Epoch 17/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.8715 - dice_coefficient: 0.8661 - iou_metric: 0.7794 - loss: 0.6453
# Epoch 17: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 65s 620ms/step - accuracy: 0.8715 - dice_coefficient: 0.8661 - iou_metric: 0.7794 - loss: 0.6454 - val_accuracy: 0.8105 - val_dice_coefficient: 0.8080 - val_iou_metric: 0.7196 - val_loss: 0.8712 - learning_rate: 5.0000e-04
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - accuracy: 0.8741 - dice_coefficient: 0.8690 - iou_metric: 0.7831 - loss: 0.6438
# Epoch 18: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 66s 626ms/step - accuracy: 0.8742 - dice_coefficient: 0.8691 - iou_metric: 0.7831 - loss: 0.6437 - val_accuracy: 0.1207 - val_dice_coefficient: 0.1193 - val_iou_metric: 0.0809 - val_loss: 0.9818 - learning_rate: 5.0000e-04
# Epoch 19/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - accuracy: 0.8833 - dice_coefficient: 0.8795 - iou_metric: 0.7989 - loss: 0.6270
# Epoch 19: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 82s 630ms/step - accuracy: 0.8833 - dice_coefficient: 0.8795 - iou_metric: 0.7989 - loss: 0.6269 - val_accuracy: 0.0086 - val_dice_coefficient: 0.0087 - val_iou_metric: 0.0044 - val_loss: 1.0123 - learning_rate: 5.0000e-04
# Epoch 20/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - accuracy: 0.8872 - dice_coefficient: 0.8840 - iou_metric: 0.8054 - loss: 0.6029
# Epoch 20: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 82s 628ms/step - accuracy: 0.8872 - dice_coefficient: 0.8839 - iou_metric: 0.8053 - loss: 0.6030 - val_accuracy: 0.1194 - val_dice_coefficient: 0.1181 - val_iou_metric: 0.0797 - val_loss: 0.9808 - learning_rate: 5.0000e-04
# Epoch 21/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - accuracy: 0.8869 - dice_coefficient: 0.8835 - iou_metric: 0.8044 - loss: 0.6087
# Epoch 21: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 65s 617ms/step - accuracy: 0.8869 - dice_coefficient: 0.8835 - iou_metric: 0.8044 - loss: 0.6087 - val_accuracy: 0.0058 - val_dice_coefficient: 0.0062 - val_iou_metric: 0.0032 - val_loss: 1.0111 - learning_rate: 5.0000e-04
# Epoch 22/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - accuracy: 0.8902 - dice_coefficient: 0.8880 - iou_metric: 0.8124 - loss: 0.6087
# Epoch 22: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 84s 634ms/step - accuracy: 0.8902 - dice_coefficient: 0.8880 - iou_metric: 0.8124 - loss: 0.6086 - val_accuracy: 0.0137 - val_dice_coefficient: 0.0137 - val_iou_metric: 0.0070 - val_loss: 1.0124 - learning_rate: 5.0000e-04
# Epoch 23/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.8905 - dice_coefficient: 0.8878 - iou_metric: 0.8109 - loss: 0.5944
# Epoch 23: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 65s 620ms/step - accuracy: 0.8905 - dice_coefficient: 0.8878 - iou_metric: 0.8110 - loss: 0.5943 - val_accuracy: 0.0137 - val_dice_coefficient: 0.0137 - val_iou_metric: 0.0070 - val_loss: 1.0130 - learning_rate: 5.0000e-04
# Epoch 24/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - accuracy: 0.8934 - dice_coefficient: 0.8909 - iou_metric: 0.8152 - loss: 0.5890
# Epoch 24: val_loss did not improve from 0.86665
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 83s 629ms/step - accuracy: 0.8934 - dice_coefficient: 0.8909 - iou_metric: 0.8153 - loss: 0.5890 - val_accuracy: 0.0271 - val_dice_coefficient: 0.0313 - val_iou_metric: 0.0184 - val_loss: 1.0091 - learning_rate: 5.0000e-04
# Epoch 25/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.8905 - dice_coefficient: 0.8881 - iou_metric: 0.8113 - loss: 0.5898
# Epoch 25: val_loss did not improve from 0.86665
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 65s 623ms/step - accuracy: 0.8905 - dice_coefficient: 0.8881 - iou_metric: 0.8113 - loss: 0.5897 - val_accuracy: 0.1214 - val_dice_coefficient: 0.1201 - val_iou_metric: 0.0818 - val_loss: 0.9808 - learning_rate: 5.0000e-04
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 5.
#
# Evaluación final (usando el mejor modelo guardado):
# Error loading best_model.keras: Exception encountered when calling Lambda.call().
#
# We could not automatically infer the shape of the Lambda's output. Please specify the `output_shape` argument for this Lambda layer.
#
# Arguments received by Lambda.call():
#   • args=('<KerasTensor shape=(None, 32, 32, 128), dtype=float32, sparse=False, name=keras_tensor_1347>',)
#   • kwargs={'mask': 'None'}
# Cannot evaluate best model from file. Displaying metrics from training history instead.
#
# Best epoch (based on validation loss): 5
# Best Validation Loss: 0.8666
# Best Validation IoU: 0.6895
# Best Validation DICE: 0.7897
# Best Validation Accuracy: 0.7919
#
# Visualizing Training History:
# Visualizing Predictions from Best Model:
# Using the last trained model for visualization as best_model could not be loaded.
